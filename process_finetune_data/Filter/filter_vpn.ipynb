# %% [markdown]
# # For filter
#
# * use ISCXVPN as a demo
# * Statistic many pkts information
# * Filter many unrelated protocols
# * VPN - {VPN/NoVPN}/{pcap}
# * TLS - {Benigh/Malware}/{pcap}

# %%
import os
import logging
import scapy.all as scapy
import scapy.contrib.igmp as igmp
import scapy.contrib.igmpv3 as igmpv3
from collections import defaultdict

os.chdir('/root/data')

import logging

logging.basicConfig(       
    level=logging.INFO,            
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',  
    handlers=[
        logging.FileHandler('logs/filter_vpn.log', mode='w'),  
        logging.StreamHandler()          
    ],
    force=True
)

logger = logging.getLogger()

# %%
data_path = 'ISCX-VPN-2016/pcap'
output_path = 'ISCX-VPN-2016/filtered'

# %%
import pandas as pd
import os

def save_to_csv(data, filename, csv_path):
    # Check if the CSV file already exists
    if os.path.exists(csv_path):
        # Load the existing CSV file
        df_existing = pd.read_csv(csv_path)
    else:
        # Create an empty DataFrame if the CSV file does not exist
        df_existing = pd.DataFrame()

    df_new = pd.DataFrame([{'filename' : filename}])
    df_new = df_new.assign(**data)

    # Combine the existing DataFrame with the new DataFrame
    df_combined = pd.concat([df_existing, df_new])
    df_combined = df_combined.fillna(0)
    df_combined.to_csv(csv_path, index=False)

# %%
protocols = {
    'network_management_protocols': ['icmp', 'icmpv6', 'dhcp', 'dhcpv6', 'igmp', 'snmp', 'arp', 'cops'],
    'nat_protocols': ['nat-pmp', 'rsip'],
    'route_management_protocols': ['db-lsp', 'db-lsp-disc', 'pathport', 'stp', 'bfd_echo', 'bgp', 'ecmp'],
    'service_management_protocols': ['ssdp', 'lldp', 'srvloc', 'ipxsap', 'opa', 'cbsp'],
    'link-local_protocols': ['llmnr', 'nbns', 'mdns', 'lsd'],
    'link_management_protocols': ['llc'],
    'distributed_protocols': ['thrift', 'dcerpc', 'rmi'],
    'real_time_protocols': ['rtcp', 'stun'],
    'remote_access_protocols': ['vnc', 'x11', 'msnms'],
    'network_time_protocols': ['ntp'],
    'security_protocols': ['ocsp', 'pkix-cert', 'egd', 'chargen', 'tpm', 'knet'],
    'industrial_protocols': ['r-goose', 'dcp-pft', 'dcp-af', 'nxp_802154_sniffer', 'enip', 'c1222', 'ax4000'],
    'file_protocols': ['lanman', 'bjnp', 'spoolss', 'ndps', 'laplink', 'bzr', 'cvspserver'],
    'quake_protocols': ['quake', 'quake2', 'quake3', 'quakeworld'],
    'iot_management_protocols': ['bat.vis', 'tplink-smarthome', 'coap','mqtt'],
    'mobile_protocols': ['gsm_ipa'],
    'database_protocols': ['tds']
}

# %%
import subprocess

# statistics pcap infomation
def statistics_pcap(pcap_path):
    command = f"tshark -r {pcap_path} -T fields -e _ws.col.Protocol | sort | uniq -c | sort -nr"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)

    # Process the output
    lines = result.stdout.strip().split('\n')
    protocol_counts = {}

    for line in lines:
        count, protocol = line.strip().split(maxsplit=1)
        protocol_counts[protocol] = int(count)

    return protocol_counts

def filter_pcap(pcap_path, output_path):
    rule = ""
    for type in protocols:
        for protocol in protocols[type]:
            rule += f"not {protocol} and "
    rule = rule[:-5]
    
    command = f'tshark -r {pcap_path} -Y "{rule}" -w {output_path}'
    subprocess.run(command, shell=True, capture_output=True, text=True)

# %%
# Filter
from multiprocessing import Pool, cpu_count

def process_folder(folder):
    if folder == 'Filtered':
        return

    logger.info(f"Processing folder: {folder}")
    for file in os.listdir(f'{data_path}/{folder}'):
        logger.info(f"Processing file: {file}")

        filter_pcap(f'{data_path}/{folder}/{file}', f'{output_path}/Raw/{file}')

# Get the list of folders to process
folders_to_process = [folder for folder in os.listdir(data_path) if folder != 'Filtered']

# Use multiprocessing to process each folder in parallel
with Pool(cpu_count()) as pool:
    pool.map(process_folder, folders_to_process)
    pool.close()
# Out:
# 2025-12-08 21:57:11,039 - root - INFO - Processing folder: ftp
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: sftp
# 2025-12-08 21:57:11,039 - root - INFO - Processing folder: voipbuster
# 2025-12-08 21:57:11,039 - root - INFO - Processing folder: spotify
# 2025-12-08 21:57:11,039 - root - INFO - Processing folder: netflix
# 2025-12-08 21:57:11,039 - root - INFO - Processing folder: skype
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: youtube
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: icq
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: torrent
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: aim
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: scp
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: email
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: hangout
# 2025-12-08 21:57:11,040 - root - INFO - Processing folder: vimeo
# 2025-12-08 21:57:11,042 - root - INFO - Processing file: vpn_ftps_B.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: vpn_sftp_B.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: netflix3.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: skype_audio4.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: voipbuster_4a.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: aim_chat_3b.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: vpn_bittorrent.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: vpn_icq_chat1b.pcap
# 2025-12-08 21:57:11,041 - root - INFO - Processing folder: facebook
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: vpn_hangouts_audio1.pcap
# 2025-12-08 21:57:11,042 - root - INFO - Processing folder: gmail
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: vpn_email2b.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: youtube6.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: scp1.pcap
# 2025-12-08 21:57:11,043 - root - INFO - Processing file: spotify3.pcap
# 2025-12-08 21:57:11,044 - root - INFO - Processing file: vimeo3.pcap
# 2025-12-08 21:57:11,045 - root - INFO - Processing file: gmailchat3.pcap
# 2025-12-08 21:57:11,045 - root - INFO - Processing file: facebookchat1.pcap
# 2025-12-08 21:57:11,393 - root - INFO - Processing file: vpn_aim_chat1a.pcap
# 2025-12-08 21:57:11,414 - root - INFO - Processing file: facebook_audio2b.pcap
# 2025-12-08 21:57:11,486 - root - INFO - Processing file: gmailchat2.pcap
# 2025-12-08 21:57:11,539 - root - INFO - Processing file: email2a.pcap
# 2025-12-08 21:57:11,544 - root - INFO - Processing file: vpn_icq_chat1a.pcap
# 2025-12-08 21:57:11,613 - root - INFO - Processing file: AIMchat1.pcap
# 2025-12-08 21:57:11,752 - root - INFO - Processing file: gmailchat1.pcap
# 2025-12-08 21:57:11,791 - root - INFO - Processing file: vimeo2.pcap
# 2025-12-08 21:57:11,836 - root - INFO - Processing file: email2b.pcap
# 2025-12-08 21:57:11,843 - root - INFO - Processing file: vpn_aim_chat1b.pcap
# 2025-12-08 21:57:11,968 - root - INFO - Processing file: spotify2.pcap
# 2025-12-08 21:57:12,048 - root - INFO - Processing file: aim_chat_3a.pcap
# 2025-12-08 21:57:12,107 - root - INFO - Processing file: email1a.pcap
# 2025-12-08 21:57:12,268 - root - INFO - Processing file: AIMchat2.pcap
# 2025-12-08 21:57:12,483 - root - INFO - Processing file: vpn_email2a.pcap
# 2025-12-08 21:57:12,517 - root - INFO - Processing file: ICQchat2.pcap
# 2025-12-08 21:57:12,604 - root - INFO - Processing file: facebook_audio3.pcap
# 2025-12-08 21:57:12,704 - root - INFO - Processing file: email1b.pcap
# 2025-12-08 21:57:12,720 - root - INFO - Processing file: icq_chat_3b.pcap
# 2025-12-08 21:57:12,745 - root - INFO - Processing file: vpn_spotify_A.pcap
# 2025-12-08 21:57:13,090 - root - INFO - Processing file: icq_chat_3a.pcap
# 2025-12-08 21:57:13,277 - root - INFO - Processing file: sftp_down_3a.pcap
# 2025-12-08 21:57:13,310 - root - INFO - Processing file: ICQchat1.pcap
# 2025-12-08 21:57:13,348 - root - INFO - Processing file: youtubeHTML5_1.pcap
# 2025-12-08 21:57:13,787 - root - INFO - Processing file: vimeo4.pcap
# 2025-12-08 21:57:14,503 - root - INFO - Processing file: netflix2.pcap
# 2025-12-08 21:57:15,653 - root - INFO - Processing file: voipbuster2b.pcap
# 2025-12-08 21:57:22,470 - root - INFO - Processing file: facebook_chat_4b.pcap
# 2025-12-08 21:57:22,690 - root - INFO - Processing file: facebookchat2.pcap
# 2025-12-08 21:57:22,878 - root - INFO - Processing file: facebook_audio1a.pcap
# 2025-12-08 21:57:23,509 - root - INFO - Processing file: facebookchat3.pcap
# 2025-12-08 21:57:23,726 - root - INFO - Processing file: facebook_audio1b.pcap
# 2025-12-08 21:57:24,131 - root - INFO - Processing file: voipbuster_4b.pcap
# 2025-12-08 21:57:24,390 - root - INFO - Processing file: facebook_video2b.pcap
# 2025-12-08 21:57:39,867 - root - INFO - Processing file: vpn_facebook_chat1a.pcap
# 2025-12-08 21:57:40,164 - root - INFO - Processing file: facebook_video1b.pcap
# 2025-12-08 21:57:44,074 - root - INFO - Processing file: facebook_video1a.pcap
# 2025-12-08 21:57:48,374 - root - INFO - Processing file: skype_video1a.pcap
# 2025-12-08 21:57:49,695 - root - INFO - Processing file: facebook_chat_4a.pcap
# 2025-12-08 21:57:49,912 - root - INFO - Processing file: facebook_audio2a.pcap
# 2025-12-08 21:57:51,518 - root - INFO - Processing file: vpn_facebook_audio2.pcap
# 2025-12-08 21:57:52,996 - root - INFO - Processing file: facebook_video2a.pcap
# 2025-12-08 21:58:00,379 - root - INFO - Processing file: scpUp6.pcap
# 2025-12-08 21:58:02,312 - root - INFO - Processing file: facebook_audio4.pcap
# 2025-12-08 21:58:09,564 - root - INFO - Processing file: ftps_up_2b.pcap
# 2025-12-08 21:58:09,747 - root - INFO - Processing file: vpn_sftp_A.pcap
# 2025-12-08 21:58:10,271 - root - INFO - Processing file: vimeo1.pcap
# 2025-12-08 21:58:10,867 - root - INFO - Processing file: vpn_facebook_chat1b.pcap
# 2025-12-08 21:58:11,072 - root - INFO - Processing file: hangouts_chat_4a.pcap
# 2025-12-08 21:58:11,660 - root - INFO - Processing file: vpn_hangouts_chat1a.pcap
# 2025-12-08 21:58:11,887 - root - INFO - Processing file: youtube3.pcap
# 2025-12-08 21:58:23,521 - root - INFO - Processing file: youtube5.pcap
# 2025-12-08 21:58:23,855 - root - INFO - Processing file: voipbuster3b.pcap
# 2025-12-08 21:58:32,437 - root - INFO - Processing file: hangouts_audio2b.pcap
# 2025-12-08 21:58:34,066 - root - INFO - Processing file: vpn_voipbuster1b.pcap
# 2025-12-08 21:58:34,723 - root - INFO - Processing file: hangouts_audio1b.pcap
# 2025-12-08 21:58:35,273 - root - INFO - Processing file: spotify4.pcap
# 2025-12-08 21:58:37,255 - root - INFO - Processing file: skype_chat1a.pcap
# 2025-12-08 21:58:37,553 - root - INFO - Processing file: vpn_netflix_A.pcap
# 2025-12-08 21:58:38,401 - root - INFO - Processing file: hangouts_video2a.pcap
# 2025-12-08 21:58:38,460 - root - INFO - Processing file: sftp1.pcap
# 2025-12-08 21:58:39,236 - root - INFO - Processing file: skype_video1b.pcap
# 2025-12-08 21:58:42,489 - root - INFO - Processing file: ftps_down_1a.pcap
# 2025-12-08 21:58:43,689 - root - INFO - Processing file: spotify1.pcap
# 2025-12-08 21:58:46,390 - root - INFO - Processing file: voipbuster1b.pcap
# 2025-12-08 21:58:48,569 - root - INFO - Processing file: vpn_voipbuster1a.pcap
# 2025-12-08 21:59:21,155 - root - INFO - Processing file: vpn_vimeo_A.pcap
# 2025-12-08 21:59:25,515 - root - INFO - Processing file: youtube2.pcap
# 2025-12-08 21:59:25,877 - root - INFO - Processing file: vpn_skype_chat1b.pcap
# 2025-12-08 21:59:26,424 - root - INFO - Processing file: skype_file6.pcap
# 2025-12-08 21:59:28,769 - root - INFO - Processing file: vpn_youtube_A.pcap
# 2025-12-08 21:59:29,661 - root - INFO - Processing file: scpUp2.pcap
# 2025-12-08 21:59:36,304 - root - INFO - Processing file: vpn_skype_files1a.pcap
# 2025-12-08 21:59:38,190 - root - INFO - Processing file: skype_audio3.pcap
# 2025-12-08 21:59:38,296 - root - INFO - Processing file: vpn_vimeo_B.pcap
# 2025-12-08 21:59:49,961 - root - INFO - Processing file: skype_file5.pcap
# 2025-12-08 21:59:50,286 - root - INFO - Processing file: skype_file1.pcap
# 2025-12-08 21:59:52,553 - root - INFO - Processing file: skype_video2b.pcap
# 2025-12-08 21:59:57,565 - root - INFO - Processing file: youtube4.pcap
# 2025-12-08 22:00:10,273 - root - INFO - Processing file: youtube1.pcap
# 2025-12-08 22:00:46,535 - root - INFO - Processing file: sftpDown1.pcap
# 2025-12-08 22:00:46,736 - root - INFO - Processing file: hangouts_audio2a.pcap
# 2025-12-08 22:00:47,158 - root - INFO - Processing file: sftp_up_2a.pcap
# 2025-12-08 22:00:49,465 - root - INFO - Processing file: hangouts_audio4.pcap
# 2025-12-08 22:01:06,438 - root - INFO - Processing file: netflix1.pcap
# 2025-12-08 22:01:07,028 - root - INFO - Processing file: sftpDown2.pcap
# 2025-12-08 22:01:12,606 - root - INFO - Processing file: sftp_up_2b.pcap
# 2025-12-08 22:01:18,667 - root - INFO - Processing file: netflix4.pcap
# 2025-12-08 22:01:20,185 - root - INFO - Processing file: sftp_down_3b.pcap
# 2025-12-08 22:01:25,241 - root - INFO - Processing file: scpDown6.pcap
# 2025-12-08 22:01:26,492 - root - INFO - Processing file: hangouts_audio1a.pcap
# 2025-12-08 22:01:28,919 - root - INFO - Processing file: hangouts_video1b.pcap
# 2025-12-08 22:01:34,233 - root - INFO - Processing file: sftpUp1.pcap
# 2025-12-08 22:01:59,520 - root - INFO - Processing file: scpDown5.pcap
# 2025-12-08 22:02:12,922 - root - INFO - Processing file: skype_file3.pcap
# 2025-12-08 22:02:14,968 - root - INFO - Processing file: vpn_hangouts_audio2.pcap
# 2025-12-08 22:02:15,047 - root - INFO - Processing file: skype_audio1b.pcap
# 2025-12-08 22:02:16,629 - root - INFO - Processing file: vpn_skype_chat1a.pcap
# 2025-12-08 22:02:17,026 - root - INFO - Processing file: skype_file4.pcap
# 2025-12-08 22:02:17,276 - root - INFO - Processing file: skype_audio1a.pcap
# 2025-12-08 22:02:18,153 - root - INFO - Processing file: skype_file2.pcap
# 2025-12-08 22:02:18,512 - root - INFO - Processing file: skype_file8.pcap
# 2025-12-08 22:02:22,105 - root - INFO - Processing file: scpUp1.pcap
# 2025-12-08 22:02:28,826 - root - INFO - Processing file: hangouts_video2b.pcap
# 2025-12-08 22:03:30,885 - root - INFO - Processing file: skype_audio2b.pcap
# 2025-12-08 22:03:32,650 - root - INFO - Processing file: vpn_skype_audio2.pcap
# 2025-12-08 22:03:34,000 - root - INFO - Processing file: scpDown1.pcap
# 2025-12-08 22:03:34,317 - root - INFO - Processing file: scpDown3.pcap
# 2025-12-08 22:03:38,837 - root - INFO - Processing file: scpDown2.pcap
# 2025-12-08 22:03:38,838 - root - INFO - Processing file: vpn_skype_files1b.pcap
# 2025-12-08 22:03:41,543 - root - INFO - Processing file: scpUp5.pcap
# 2025-12-08 22:03:41,749 - root - INFO - Processing file: scpDown4.pcap
# 2025-12-08 22:03:41,790 - root - INFO - Processing file: skype_video2a.pcap
# 2025-12-08 22:03:41,962 - root - INFO - Processing file: scpUp3.pcap
# 2025-12-08 22:05:05,328 - root - INFO - Processing file: vpn_hangouts_chat1b.pcap
# 2025-12-08 22:05:09,456 - root - INFO - Processing file: hangout_chat_4b.pcap
# 2025-12-08 22:05:11,891 - root - INFO - Processing file: hangouts_audio3.pcap
# 2025-12-08 22:06:13,567 - root - INFO - Processing file: skype_audio2a.pcap
# 2025-12-08 22:06:20,425 - root - INFO - Processing file: skype_chat1b.pcap
# 2025-12-08 22:06:26,951 - root - INFO - Processing file: vpn_skype_audio1.pcap
# 2025-12-08 22:07:16,176 - root - INFO - Processing file: skype_file7.pcap
# 2025-12-08 22:10:41,330 - root - INFO - Processing file: ftps_down_1b.pcap
# 2025-12-08 22:11:46,437 - root - INFO - Processing file: ftps_up_2a.pcap
# 2025-12-08 22:11:50,477 - root - INFO - Processing file: vpn_ftps_A.pcap

# %%
# statistics the protocol counts
# seperate the pcap filter and statistics, just for acceleration

for folder in os.listdir(data_path):
    if folder == 'Filtered':
        continue

    logger.info(f"Processing folder: {folder}")
    for file in os.listdir(f'{data_path}/{folder}'):
        logger.info(f"Processing file: {file}")

        # Statistics the protocol counts
        origin_protocol_counts = statistics_pcap(f'{data_path}/{folder}/{file}')
        save_to_csv(origin_protocol_counts, file, f'./results/raw_protocol_counts.csv')
        logger.info(f"Original packets {folder}/{file}: {origin_protocol_counts}")

        filtered_protocol_counts = statistics_pcap(f'{output_path}/Raw/{file}')
        save_to_csv(filtered_protocol_counts, file, f'./results/filtered_protocol_counts.csv')
        logger.info(f"Filtered packets {folder}/{file}: {filtered_protocol_counts}")
# Out:
# 2025-12-08 23:15:42,291 - root - INFO - Processing folder: netflix
# 2025-12-08 23:15:42,292 - root - INFO - Processing file: netflix3.pcap
# 2025-12-08 23:15:46,052 - root - INFO - Original packets netflix/netflix3.pcap: {'TCP': 121786, 'HTTP': 322, 'TLSv1.2': 187, 'ICMP': 39, 'DNS': 21, 'ARP': 8, 'BROWSER': 7, 'TLSv1': 6, 'NBNS': 4}
# 2025-12-08 23:15:50,506 - root - INFO - Filtered packets netflix/netflix3.pcap: {'TCP': 121786, 'HTTP': 322, 'TLSv1.2': 187, 'DNS': 21, 'BROWSER': 7, 'TLSv1': 6}
# 2025-12-08 23:15:50,507 - root - INFO - Processing file: netflix2.pcap
# 2025-12-08 23:15:52,807 - root - INFO - Original packets netflix/netflix2.pcap: {'TCP': 51451, 'HTTP': 269, 'TLSv1.2': 72, 'DNS': 12, 'ICMP': 11, 'ARP': 4, 'BROWSER': 3, 'TLSv1': 2, 'NBNS': 2}
# 2025-12-08 23:15:55,099 - root - INFO - Filtered packets netflix/netflix2.pcap: {'TCP': 51451, 'HTTP': 269, 'TLSv1.2': 72, 'DNS': 12, 'BROWSER': 3, 'TLSv1': 2}
# 2025-12-08 23:15:55,101 - root - INFO - Processing file: vpn_netflix_A.pcap
# 2025-12-08 23:16:16,420 - root - INFO - Original packets netflix/vpn_netflix_A.pcap: {'TCP': 867961, 'HTTP': 1275, 'TLSv1.2': 349, 'GQUIC': 139, 'TLSv1': 123, 'DNS': 60, 'DB-LSP-DISC/JSON': 59, 'ICMP': 47, 'HTTP/JSON': 5}
# 2025-12-08 23:16:38,583 - root - INFO - Filtered packets netflix/vpn_netflix_A.pcap: {'TCP': 867961, 'HTTP': 1275, 'TLSv1.2': 349, 'GQUIC': 139, 'TLSv1': 123, 'DNS': 60, 'HTTP/JSON': 5}
# 2025-12-08 23:16:38,584 - root - INFO - Processing file: netflix1.pcap
# 2025-12-08 23:16:40,980 - root - INFO - Original packets netflix/netflix1.pcap: {'TCP': 51442, 'HTTP': 330, 'TLSv1.2': 105, 'DNS': 30, 'ICMP': 7, 'HTTP/JSON': 5, 'BROWSER': 4, 'ARP': 4, 'TLSv1': 2, 'NBNS': 2, 'HTTP/XML': 1}
# 2025-12-08 23:16:43,380 - root - INFO - Filtered packets netflix/netflix1.pcap: {'TCP': 51442, 'HTTP': 330, 'TLSv1.2': 105, 'DNS': 30, 'HTTP/JSON': 5, 'BROWSER': 4, 'TLSv1': 2, 'HTTP/XML': 1}
# 2025-12-08 23:16:43,381 - root - INFO - Processing file: netflix4.pcap
# 2025-12-08 23:16:46,454 - root - INFO - Original packets netflix/netflix4.pcap: {'TCP': 72470, 'HTTP': 444, 'TLSv1.2': 133, 'ICMP': 40, 'DNS': 36, 'BROWSER': 7, 'TLSv1': 6, 'ARP': 6, 'HTTP/JSON': 3, 'NBNS': 2}
# 2025-12-08 23:16:49,570 - root - INFO - Filtered packets netflix/netflix4.pcap: {'TCP': 72470, 'HTTP': 444, 'TLSv1.2': 133, 'DNS': 36, 'BROWSER': 7, 'TLSv1': 6, 'HTTP/JSON': 3}
# 2025-12-08 23:16:49,571 - root - INFO - Processing folder: spotify
# 2025-12-08 23:16:49,571 - root - INFO - Processing file: spotify3.pcap
# 2025-12-08 23:16:49,881 - root - INFO - Original packets spotify/spotify3.pcap: {'TCP': 2919, 'TLSv1.2': 153, 'ICMP': 93, 'SMB2': 44, 'UDP': 25, 'ARP': 20, 'DNS': 18, 'BROWSER': 13, 'TLSv1.1': 12, 'NBNS': 6, 'TLSv1': 5, 'SPOOLSS': 4, 'DCERPC': 4, 'SMB': 2, 'HTTP': 2}
# 2025-12-08 23:16:50,262 - root - INFO - Filtered packets spotify/spotify3.pcap: {'TCP': 2919, 'TLSv1.2': 153, 'SMB2': 44, 'UDP': 25, 'DNS': 18, 'BROWSER': 13, 'TLSv1.1': 12, 'TLSv1': 5, 'SMB': 2, 'HTTP': 2}
# 2025-12-08 23:16:50,263 - root - INFO - Processing file: spotify2.pcap
# 2025-12-08 23:16:50,523 - root - INFO - Original packets spotify/spotify2.pcap: {'TCP': 595, 'TLSv1.2': 49, 'HTTP': 22, 'ICMP': 19, 'UDP': 18, 'DNS': 14, 'ARP': 8, 'BROWSER': 5, 'NBNS': 4, 'TLSv1': 2, 'MDNS': 1}
# 2025-12-08 23:16:50,730 - root - INFO - Filtered packets spotify/spotify2.pcap: {'TCP': 595, 'TLSv1.2': 49, 'HTTP': 22, 'UDP': 18, 'DNS': 14, 'BROWSER': 5, 'TLSv1': 2}
# 2025-12-08 23:16:50,731 - root - INFO - Processing file: vpn_spotify_A.pcap
# 2025-12-08 23:16:53,681 - root - INFO - Original packets spotify/vpn_spotify_A.pcap: {'TCP': 114368, 'HTTP': 380, 'GQUIC': 290, 'TLSv1.2': 286, 'TLSv1': 226, 'UDP': 130, 'DB-LSP-DISC/JSON': 129, 'DNS': 63, 'TLSv1.1': 44, 'ICMP': 18, 'HTTP/XML': 4, 'HTTP/JSON': 1}
# 2025-12-08 23:16:57,233 - root - INFO - Filtered packets spotify/vpn_spotify_A.pcap: {'TCP': 114368, 'HTTP': 380, 'GQUIC': 290, 'TLSv1.2': 286, 'TLSv1': 226, 'UDP': 130, 'DNS': 63, 'TLSv1.1': 42, 'HTTP/XML': 4, 'HTTP/JSON': 1}
# 2025-12-08 23:16:57,234 - root - INFO - Processing file: spotify4.pcap
# 2025-12-08 23:16:58,171 - root - INFO - Original packets spotify/spotify4.pcap: {'TCP': 22065, 'TLSv1.2': 165, 'HTTP': 151, 'ICMP': 106, 'UDP': 66, 'DNS': 52, 'SMB2': 44, 'ARP': 36, 'BROWSER': 29, 'NBNS': 12, 'TLSv1': 9, 'TLSv1.1': 8, 'SPOOLSS': 4, 'DCERPC': 4, 'SMB': 2, 'SSDP': 1, 'NTP': 1}
# 2025-12-08 23:16:59,201 - root - INFO - Filtered packets spotify/spotify4.pcap: {'TCP': 22065, 'TLSv1.2': 165, 'HTTP': 151, 'UDP': 66, 'DNS': 52, 'SMB2': 44, 'BROWSER': 29, 'TLSv1': 9, 'TLSv1.1': 8, 'SMB': 2}
# 2025-12-08 23:16:59,202 - root - INFO - Processing file: spotify1.pcap
# 2025-12-08 23:16:59,918 - root - INFO - Original packets spotify/spotify1.pcap: {'TCP': 13197, 'TLSv1.1': 551, 'HTTP': 375, 'ICMP': 100, 'TLSv1.2': 92, 'DNS': 54, 'UDP': 28, 'TLSv1': 18, 'BROWSER': 12, 'ARP': 10, 'NBNS': 4, 'HTTP/JSON': 1}
# 2025-12-08 23:17:00,549 - root - INFO - Filtered packets spotify/spotify1.pcap: {'TCP': 13197, 'TLSv1.1': 543, 'HTTP': 375, 'TLSv1.2': 92, 'DNS': 54, 'UDP': 28, 'TLSv1': 18, 'BROWSER': 12, 'HTTP/JSON': 1}
# 2025-12-08 23:17:00,550 - root - INFO - Processing folder: skype
# 2025-12-08 23:17:00,551 - root - INFO - Processing file: skype_audio4.pcap
# 2025-12-08 23:17:04,879 - root - INFO - Original packets skype/skype_audio4.pcap: {'UDP': 252663, 'TCP': 1623, 'WireGuard': 918, 'RTCP': 324, 'SSDP': 240, 'TLSv1': 214, 'TLSv1.2': 200, 'ICMP': 129, 'ARP': 98, 'BROWSER': 67, 'DHCPv6': 48, 'DNS': 34, 'LLMNR': 32, 'NBNS': 28, 'THRIFT': 10, 'HTTP': 6, 'HTTP/XML': 4, 'LLDP': 3}
# 2025-12-08 23:17:09,388 - root - INFO - Filtered packets skype/skype_audio4.pcap: {'UDP': 252663, 'TCP': 1623, 'WireGuard': 918, 'TLSv1': 214, 'TLSv1.2': 200, 'BROWSER': 67, 'DNS': 34, 'HTTP': 6, 'HTTP/XML': 4}
# 2025-12-08 23:17:09,389 - root - INFO - Processing file: skype_video1a.pcap
# 2025-12-08 23:17:11,954 - root - INFO - Original packets skype/skype_video1a.pcap: {'UDP': 140022, 'TCP': 197, 'RTCP': 152, 'ARP': 78, 'ICMP': 70, 'TLSv1.2': 9, 'GQUIC': 7, 'TLSv1': 6, 'THRIFT': 6, 'DNS': 6, 'WireGuard': 5, 'NBNS': 4, 'Pathport': 3, 'BROWSER': 2, 'R-GOOSE': 1, 'NTP': 1}
# 2025-12-08 23:17:14,651 - root - INFO - Filtered packets skype/skype_video1a.pcap: {'UDP': 140022, 'TCP': 197, 'TLSv1.2': 9, 'GQUIC': 7, 'TLSv1': 6, 'DNS': 6, 'WireGuard': 5, 'BROWSER': 2}
# 2025-12-08 23:17:14,652 - root - INFO - Processing file: skype_chat1a.pcap
# 2025-12-08 23:17:15,614 - root - INFO - Original packets skype/skype_chat1a.pcap: {'ARP': 19046, 'TCP': 14605, 'LLMNR': 6062, 'NBNS': 4523, 'MDNS': 2549, 'TLSv1': 1623, 'UDP': 1556, 'DB-LSP-DISC/JSON': 768, 'SNMP': 590, 'ICMPv6': 546, 'DHCPv6': 525, 'BROWSER': 337, 'TLSv1.2': 281, 'SSDP': 278, 'STP': 193, 'DNS': 166, 'IGMPv2': 102, 'IPX SAP': 64, 'NTP': 48, 'HTTP': 34, 'LLDP': 33, 'DHCP': 23, 'IGMPv3': 17, 'X11': 7, 'LLC': 6, 'XMPP/XML': 4, 'OCSP': 4, 'SSL': 3, 'SSLv2': 1, 'SRVLOC': 1, 'BT-DHT': 1}
# 2025-12-08 23:17:16,181 - root - INFO - Filtered packets skype/skype_chat1a.pcap: {'TCP': 13984, 'TLSv1': 1623, 'UDP': 1556, 'BROWSER': 337, 'TLSv1.2': 281, 'DNS': 166, 'HTTP': 34, 'XMPP/XML': 4, 'SSL': 3, 'SSLv2': 1, 'BT-DHT': 1}
# 2025-12-08 23:17:16,183 - root - INFO - Processing file: skype_video1b.pcap
# 2025-12-08 23:17:21,505 - root - INFO - Original packets skype/skype_video1b.pcap: {'UDP': 140103, 'TCP': 113641, 'HTTP': 1012, 'TLSv1.2': 278, 'ARP': 156, 'RTCP': 152, 'DNS': 68, 'TLSv1': 56, 'NBNS': 45, 'THRIFT': 6, 'WireGuard': 5, 'OCSP': 5, 'Pathport': 3, 'DHCP': 2, 'R-GOOSE': 1}
# 2025-12-08 23:17:27,022 - root - INFO - Filtered packets skype/skype_video1b.pcap: {'UDP': 140103, 'TCP': 113641, 'HTTP': 1012, 'TLSv1.2': 277, 'DNS': 68, 'TLSv1': 56, 'WireGuard': 5}
# 2025-12-08 23:17:27,023 - root - INFO - Processing file: vpn_skype_chat1b.pcap
# 2025-12-08 23:17:27,370 - root - INFO - Original packets skype/vpn_skype_chat1b.pcap: {'TCP': 7053, 'TLSv1': 477, 'UDP': 70, 'NTP': 2}
# 2025-12-08 23:17:27,676 - root - INFO - Filtered packets skype/vpn_skype_chat1b.pcap: {'TCP': 7053, 'TLSv1': 477, 'UDP': 70}
# 2025-12-08 23:17:27,677 - root - INFO - Processing file: skype_file6.pcap
# 2025-12-08 23:17:29,028 - root - INFO - Original packets skype/skype_file6.pcap: {'UDP': 64553, 'TCP': 1537, 'TLSv1.2': 185, 'TLSv1': 121, 'ARP': 108, 'HTTP': 56, 'RTCP': 2, 'R-GOOSE': 2, 'THRIFT': 1, 'Pathport': 1}
# 2025-12-08 23:17:30,440 - root - INFO - Filtered packets skype/skype_file6.pcap: {'UDP': 64553, 'TCP': 1537, 'TLSv1.2': 183, 'TLSv1': 121, 'HTTP': 56}
# 2025-12-08 23:17:30,441 - root - INFO - Processing file: vpn_skype_files1a.pcap
# 2025-12-08 23:17:31,300 - root - INFO - Original packets skype/vpn_skype_files1a.pcap: {'TCP': 33669, 'UDP': 8145, 'ICMP': 674, 'TLSv1': 435, 'NTP': 6, 'DNS': 6, 'RTCP': 1}
# 2025-12-08 23:17:32,240 - root - INFO - Filtered packets skype/vpn_skype_files1a.pcap: {'TCP': 33669, 'UDP': 8145, 'TLSv1': 435, 'DNS': 6}
# 2025-12-08 23:17:32,241 - root - INFO - Processing file: skype_audio3.pcap
# 2025-12-08 23:17:38,511 - root - INFO - Original packets skype/skype_audio3.pcap: {'UDP': 253418, 'LLMNR': 78004, 'ARP': 41768, 'NBNS': 35720, 'MDNS': 2124, 'DB-LSP-DISC/JSON': 1970, 'DHCPv6': 1534, 'ICMPv6': 1416, 'WireGuard': 766, 'TCP': 714, 'SSDP': 679, 'BROWSER': 501, 'STP': 494, 'IGMPv2': 355, 'RTCP': 323, 'NTP': 289, 'IPX SAP': 164, 'ICMP': 121, 'TLSv1': 96, 'LLDP': 83, 'DHCP': 36, 'LLC': 18, 'IGMPv3': 16, 'SRVLOC': 15, 'THRIFT': 10}
# 2025-12-08 23:17:43,041 - root - INFO - Filtered packets skype/skype_audio3.pcap: {'UDP': 253418, 'WireGuard': 766, 'TCP': 714, 'BROWSER': 501, 'TLSv1': 96}
# 2025-12-08 23:17:43,042 - root - INFO - Processing file: skype_file5.pcap
# 2025-12-08 23:17:43,270 - root - INFO - Original packets skype/skype_file5.pcap: {'TCP': 591, 'UDP': 560, 'TLSv1': 53, 'ARP': 30, 'XMPP/XML': 1, 'RTCP': 1}
# 2025-12-08 23:17:43,481 - root - INFO - Filtered packets skype/skype_file5.pcap: {'TCP': 591, 'UDP': 560, 'TLSv1': 53, 'XMPP/XML': 1}
# 2025-12-08 23:17:43,482 - root - INFO - Processing file: skype_file1.pcap
# 2025-12-08 23:17:43,690 - root - INFO - Original packets skype/skype_file1.pcap: {'UDP': 454, 'TCP': 273, 'HTTP': 20, 'TLSv1': 12, 'DNS': 8, 'TLSv1.2': 7, 'ARP': 4, 'ICMP': 2}
# 2025-12-08 23:17:43,887 - root - INFO - Filtered packets skype/skype_file1.pcap: {'UDP': 454, 'TCP': 273, 'HTTP': 20, 'TLSv1': 12, 'DNS': 8, 'TLSv1.2': 7}
# 2025-12-08 23:17:43,888 - root - INFO - Processing file: skype_video2b.pcap
# 2025-12-08 23:18:05,048 - root - INFO - Original packets skype/skype_video2b.pcap: {'TCP': 557637, 'UDP': 282443, 'HTTP': 1018, 'RTCP': 345, 'ARP': 304, 'TLSv1.2': 230, 'TLSv1': 144, 'DNS': 46, 'WireGuard': 12, 'THRIFT': 11, 'SSLv2': 7, 'NBNS': 6, 'Pathport': 5, 'LLMNR': 2, 'DHCP': 2}
# 2025-12-08 23:18:27,489 - root - INFO - Filtered packets skype/skype_video2b.pcap: {'TCP': 557637, 'UDP': 282443, 'HTTP': 1018, 'TLSv1.2': 230, 'TLSv1': 144, 'DNS': 46, 'WireGuard': 12, 'SSLv2': 7}
# 2025-12-08 23:18:27,490 - root - INFO - Processing file: skype_file3.pcap
# 2025-12-08 23:18:28,800 - root - INFO - Original packets skype/skype_file3.pcap: {'UDP': 64472, 'TCP': 686, 'TLSv1': 73, 'ARP': 40, 'ICMP': 15, 'TLSv1.2': 11, 'GQUIC': 7, 'DNS': 6, 'BROWSER': 4, 'RTCP': 2, 'R-GOOSE': 2, 'NBNS': 2, 'THRIFT': 1, 'Pathport': 1, 'MDNS': 1}
# 2025-12-08 23:18:30,131 - root - INFO - Filtered packets skype/skype_file3.pcap: {'UDP': 64472, 'TCP': 686, 'TLSv1': 73, 'TLSv1.2': 11, 'GQUIC': 7, 'DNS': 6, 'BROWSER': 4}
# 2025-12-08 23:18:30,132 - root - INFO - Processing file: skype_audio1b.pcap
# 2025-12-08 23:18:31,376 - root - INFO - Original packets skype/skype_audio1b.pcap: {'UDP': 59435, 'TCP': 3344, 'TLSv1.1': 972, 'TLSv1.2': 753, 'ARP': 204, 'TLSv1': 128, 'DNS': 98, 'HTTP': 87, 'NBNS': 84, 'RTCP': 66, 'OCSP': 12, 'SSL': 8, 'WireGuard': 6, 'DHCP': 4, 'ICMP': 3, 'THRIFT': 2, 'SSLv3': 2, 'SSLv2': 1, 'SSDP': 1, 'R-GOOSE': 1, 'Pathport': 1}
# 2025-12-08 23:18:32,714 - root - INFO - Filtered packets skype/skype_audio1b.pcap: {'UDP': 59435, 'TCP': 3344, 'TLSv1.1': 972, 'TLSv1.2': 751, 'TLSv1': 126, 'DNS': 98, 'HTTP': 87, 'SSL': 8, 'WireGuard': 6, 'SSLv3': 2, 'SSLv2': 1}
# 2025-12-08 23:18:32,715 - root - INFO - Processing file: vpn_skype_chat1a.pcap
# 2025-12-08 23:18:33,020 - root - INFO - Original packets skype/vpn_skype_chat1a.pcap: {'TCP': 6457, 'TLSv1': 439, 'UDP': 68, 'DNS': 6, 'ICMP': 3}
# 2025-12-08 23:18:33,325 - root - INFO - Filtered packets skype/vpn_skype_chat1a.pcap: {'TCP': 6457, 'TLSv1': 439, 'UDP': 68, 'DNS': 6}
# 2025-12-08 23:18:33,326 - root - INFO - Processing file: skype_file4.pcap
# 2025-12-08 23:18:33,513 - root - INFO - Original packets skype/skype_file4.pcap: {'TCP': 327, 'TLSv1.2': 48, 'UDP': 35, 'TLSv1': 31, 'ARP': 12, 'DNS': 2}
# 2025-12-08 23:18:33,708 - root - INFO - Filtered packets skype/skype_file4.pcap: {'TCP': 327, 'TLSv1.2': 48, 'UDP': 35, 'TLSv1': 31, 'DNS': 2}
# 2025-12-08 23:18:33,709 - root - INFO - Processing file: skype_audio1a.pcap
# 2025-12-08 23:18:34,907 - root - INFO - Original packets skype/skype_audio1a.pcap: {'UDP': 59161, 'TCP': 695, 'ARP': 92, 'RTCP': 66, 'TLSv1.2': 52, 'GQUIC': 43, 'SMB2': 21, 'DNS': 20, 'TLSv1': 17, 'ICMP': 11, 'BROWSER': 9, 'WireGuard': 6, 'NBNS': 4, 'THRIFT': 2, 'SPOOLSS': 2, 'DCERPC': 2, 'SMB': 1, 'R-GOOSE': 1, 'Pathport': 1, 'MDNS': 1}
# 2025-12-08 23:18:36,093 - root - INFO - Filtered packets skype/skype_audio1a.pcap: {'UDP': 59161, 'TCP': 695, 'TLSv1.2': 52, 'GQUIC': 43, 'SMB2': 21, 'DNS': 20, 'TLSv1': 17, 'BROWSER': 9, 'WireGuard': 6, 'SMB': 1}
# 2025-12-08 23:18:36,094 - root - INFO - Processing file: skype_file2.pcap
# 2025-12-08 23:18:36,426 - root - INFO - Original packets skype/skype_file2.pcap: {'UDP': 3755, 'TCP': 602, 'TLSv1.2': 144, 'TLSv1': 40, 'GQUIC': 27, 'DNS': 22, 'ARP': 12, 'HTTP': 4, 'ICMP': 1}
# 2025-12-08 23:18:36,705 - root - INFO - Filtered packets skype/skype_file2.pcap: {'UDP': 3755, 'TCP': 602, 'TLSv1.2': 144, 'TLSv1': 40, 'GQUIC': 27, 'DNS': 22, 'HTTP': 4}
# 2025-12-08 23:18:36,706 - root - INFO - Processing file: skype_file8.pcap
# 2025-12-08 23:18:48,774 - root - INFO - Original packets skype/skype_file8.pcap: {'UDP': 512860, 'LLMNR': 127068, 'ARP': 60438, 'NBNS': 55447, 'MDNS': 6577, 'DB-LSP-DISC/JSON': 2960, 'DHCPv6': 2460, 'ICMPv6': 2229, 'TCP': 2225, 'SSDP': 1121, 'BROWSER': 822, 'STP': 808, 'IGMPv2': 556, 'ICMP': 538, 'NTP': 472, 'IPX SAP': 272, 'TLSv1': 182, 'LLDP': 134, 'DHCP': 71, 'IGMPv3': 47, 'SRVLOC': 34, 'LLC': 32, 'THRIFT': 16, 'Pathport': 10, 'BJNP': 10, 'DNS': 8, 'R-GOOSE': 3, 'RTCP': 1}
# 2025-12-08 23:18:59,118 - root - INFO - Filtered packets skype/skype_file8.pcap: {'UDP': 512860, 'TCP': 2225, 'BROWSER': 822, 'TLSv1': 182, 'DNS': 8}
# 2025-12-08 23:18:59,119 - root - INFO - Processing file: skype_audio2b.pcap
# 2025-12-08 23:19:00,455 - root - INFO - Original packets skype/skype_audio2b.pcap: {'UDP': 58877, 'TCP': 4516, 'TLSv1.2': 353, 'ARP': 218, 'TLSv1': 88, 'RTCP': 57, 'HTTP': 35, 'DNS': 14, 'WireGuard': 8, 'NBNS': 6, 'SSL': 5, 'DHCP': 2, 'SSLv3': 1, 'SSLv2': 1, 'R-GOOSE': 1, 'OCSP': 1, 'IGMPv2': 1}
# 2025-12-08 23:19:01,725 - root - INFO - Filtered packets skype/skype_audio2b.pcap: {'UDP': 58877, 'TCP': 4516, 'TLSv1.2': 352, 'TLSv1': 88, 'HTTP': 35, 'DNS': 14, 'WireGuard': 8, 'SSL': 5, 'SSLv3': 1, 'SSLv2': 1}
# 2025-12-08 23:19:01,726 - root - INFO - Processing file: vpn_skype_audio2.pcap
# 2025-12-08 23:19:06,784 - root - INFO - Original packets skype/vpn_skype_audio2.pcap: {'UDP': 368823, 'TCP': 1811, 'DNS': 712, 'RTCP': 421, 'TLSv1.2': 267, 'TLSv1': 175, 'ICMP': 103, 'WireGuard': 18, 'HTTP': 18, 'OCSP': 16, 'THRIFT': 13, 'Pathport': 3, 'SSLv3': 2, 'SSL': 1}
# 2025-12-08 23:19:12,208 - root - INFO - Filtered packets skype/vpn_skype_audio2.pcap: {'UDP': 368823, 'TCP': 1811, 'DNS': 712, 'TLSv1.2': 267, 'TLSv1': 175, 'WireGuard': 18, 'HTTP': 18, 'SSLv3': 2, 'SSL': 1}
# 2025-12-08 23:19:12,209 - root - INFO - Processing file: vpn_skype_files1b.pcap
# 2025-12-08 23:19:12,954 - root - INFO - Original packets skype/vpn_skype_files1b.pcap: {'TCP': 22249, 'UDP': 8853, 'ICMP': 701, 'TLSv1': 629, 'DNS': 196, 'TLSv1.2': 118, 'SSDP': 36, 'RTCP': 17, 'HTTP': 12, 'NTP': 4, 'OCSP': 2}
# 2025-12-08 23:19:13,641 - root - INFO - Filtered packets skype/vpn_skype_files1b.pcap: {'TCP': 21993, 'UDP': 8853, 'TLSv1': 629, 'DNS': 196, 'TLSv1.2': 118, 'HTTP': 12}
# 2025-12-08 23:19:13,642 - root - INFO - Processing file: skype_video2a.pcap
# 2025-12-08 23:19:18,493 - root - INFO - Original packets skype/skype_video2a.pcap: {'UDP': 282301, 'TCP': 368, 'RTCP': 345, 'ARP': 152, 'TLSv1.2': 46, 'GQUIC': 37, 'TLSv1': 25, 'ICMP': 20, 'DNS': 14, 'BROWSER': 13, 'WireGuard': 12, 'THRIFT': 11, 'NBNS': 6, 'Pathport': 5, 'NTP': 1}
# 2025-12-08 23:19:24,241 - root - INFO - Filtered packets skype/skype_video2a.pcap: {'UDP': 282301, 'TCP': 368, 'TLSv1.2': 46, 'GQUIC': 37, 'TLSv1': 25, 'DNS': 14, 'BROWSER': 13, 'WireGuard': 12}
# 2025-12-08 23:19:24,242 - root - INFO - Processing file: skype_audio2a.pcap
# 2025-12-08 23:19:25,352 - root - INFO - Original packets skype/skype_audio2a.pcap: {'UDP': 58099, 'TCP': 239, 'ARP': 92, 'RTCP': 57, 'TLSv1.2': 21, 'GQUIC': 14, 'TLSv1': 12, 'ICMP': 12, 'WireGuard': 8, 'DNS': 6, 'NBNS': 4, 'BROWSER': 4, 'R-GOOSE': 1}
# 2025-12-08 23:19:26,494 - root - INFO - Filtered packets skype/skype_audio2a.pcap: {'UDP': 58099, 'TCP': 239, 'TLSv1.2': 21, 'GQUIC': 14, 'TLSv1': 12, 'WireGuard': 8, 'DNS': 6, 'BROWSER': 4}
# 2025-12-08 23:19:26,495 - root - INFO - Processing file: skype_chat1b.pcap
# 2025-12-08 23:19:27,459 - root - INFO - Original packets skype/skype_chat1b.pcap: {'ARP': 17787, 'TCP': 15227, 'LLMNR': 6006, 'NBNS': 4485, 'MDNS': 2544, 'TLSv1': 1567, 'UDP': 1533, 'DB-LSP-DISC/JSON': 766, 'SNMP': 728, 'ICMPv6': 572, 'DHCPv6': 538, 'STP': 478, 'SSDP': 355, 'BROWSER': 337, 'TLSv1.2': 314, 'DNS': 271, 'IGMPv2': 102, 'HTTP': 86, 'IPX SAP': 64, 'NTP': 48, 'DHCP': 23, 'IGMPv3': 17, 'LLC': 9, 'OCSP': 8, 'LLDP': 2, 'SRVLOC': 1, 'ICMP': 1}
# 2025-12-08 23:19:28,060 - root - INFO - Filtered packets skype/skype_chat1b.pcap: {'TCP': 14606, 'TLSv1': 1567, 'UDP': 1533, 'BROWSER': 337, 'TLSv1.2': 314, 'DNS': 271, 'HTTP': 86}
# 2025-12-08 23:19:28,061 - root - INFO - Processing file: vpn_skype_audio1.pcap
# 2025-12-08 23:19:33,296 - root - INFO - Original packets skype/vpn_skype_audio1.pcap: {'UDP': 370346, 'TCP': 4540, 'RTCP': 430, 'TLSv1.2': 284, 'TLSv1': 199, 'DNS': 76, 'ICMP': 70, 'WireGuard': 18, 'THRIFT': 13, 'Pathport': 3, 'SSL': 1}
# 2025-12-08 23:19:38,760 - root - INFO - Filtered packets skype/vpn_skype_audio1.pcap: {'UDP': 370346, 'TCP': 4540, 'TLSv1.2': 284, 'TLSv1': 199, 'DNS': 76, 'WireGuard': 18, 'SSL': 1}
# 2025-12-08 23:19:38,761 - root - INFO - Processing file: skype_file7.pcap
# 2025-12-08 23:19:47,488 - root - INFO - Original packets skype/skype_file7.pcap: {'UDP': 505401, 'TCP': 3447, 'TLSv1.2': 920, 'SSDP': 279, 'TLSv1': 260, 'ICMP': 155, 'DNS': 130, 'ICMPv6': 129, 'GQUIC': 129, 'ARP': 102, 'BROWSER': 79, 'HTTP': 62, 'DHCPv6': 42, 'NBNS': 41, 'LLMNR': 40, 'THRIFT': 16, 'Pathport': 10, 'HTTP/XML': 8, 'IPv6': 7, 'R-GOOSE': 3, 'LLDP': 3, 'IGMPv3': 2, 'RTCP': 1, 'OCSP': 1, 'HTTP/JSON': 1}
# 2025-12-08 23:19:56,857 - root - INFO - Filtered packets skype/skype_file7.pcap: {'UDP': 505401, 'TCP': 3447, 'TLSv1.2': 917, 'TLSv1': 260, 'DNS': 130, 'GQUIC': 129, 'BROWSER': 79, 'HTTP': 62, 'HTTP/XML': 8, 'IPv6': 7, 'HTTP/JSON': 1}
# 2025-12-08 23:19:56,858 - root - INFO - Processing folder: ftp
# 2025-12-08 23:19:56,858 - root - INFO - Processing file: vpn_ftps_B.pcap
# 2025-12-08 23:19:58,473 - root - INFO - Original packets ftp/vpn_ftps_B.pcap: {'TCP': 69125, 'TLSv1.2': 19475, 'SSLv3': 33, 'GQUIC': 22, 'FTP': 12, 'DNS': 12, 'ICMP': 4, 'TLSv1': 1, 'SSLv2': 1}
# 2025-12-08 23:20:00,494 - root - INFO - Filtered packets ftp/vpn_ftps_B.pcap: {'TCP': 69125, 'TLSv1.2': 19475, 'SSLv3': 33, 'GQUIC': 22, 'FTP': 12, 'DNS': 12, 'TLSv1': 1, 'SSLv2': 1}
# 2025-12-08 23:20:00,495 - root - INFO - Processing file: ftps_up_2b.pcap
# 2025-12-08 23:20:02,743 - root - INFO - Original packets ftp/ftps_up_2b.pcap: {'TCP': 90271, 'TLSv1.2': 2769, 'TLSv1': 45, 'X11': 27, 'SNMP': 24, 'ARP': 14, 'NBNS': 13, 'LLMNR': 12, 'UDP': 8, 'FTP': 6, 'BROWSER': 2}
# 2025-12-08 23:20:05,090 - root - INFO - Filtered packets ftp/ftps_up_2b.pcap: {'TCP': 90256, 'TLSv1.2': 2769, 'TLSv1': 45, 'X11': 15, 'UDP': 8, 'FTP': 6, 'BROWSER': 2}
# 2025-12-08 23:20:05,091 - root - INFO - Processing file: ftps_down_1a.pcap
# 2025-12-08 23:21:38,719 - root - INFO - Original packets ftp/ftps_down_1a.pcap: {'TCP': 3717126, 'TLSv1.2': 2023781, 'BT-DHT': 2186, 'UDP': 71, 'HTTP': 40, 'ICMPv6': 38, 'LLMNR': 36, 'TLSv1': 35, 'ICMP': 30, 'ARP': 30, 'SSLv2': 27, 'NBNS': 26, 'DNS': 26, 'IGMPv2': 11, 'LSD': 8, 'H1': 8, 'FTP': 7, 'IPv6': 2, 'DTLS': 2, 'SSDP': 1, 'SIP': 1, 'NTP': 1}
# 2025-12-08 23:23:16,822 - root - INFO - Filtered packets ftp/ftps_down_1a.pcap: {'TCP': 3717126, 'TLSv1.2': 2023781, 'BT-DHT': 2186, 'UDP': 71, 'HTTP': 40, 'TLSv1': 35, 'SSLv2': 27, 'DNS': 26, 'H1': 8, 'FTP': 7, 'IPv6': 2, 'DTLS': 2, 'SIP': 1}
# 2025-12-08 23:23:16,834 - root - INFO - Processing file: ftps_down_1b.pcap
# 2025-12-08 23:23:47,352 - root - INFO - Original packets ftp/ftps_down_1b.pcap: {'TCP': 1805557, 'TLSv1.2': 136081, 'SNMP': 962, 'ARP': 67, 'UDP': 51, 'LLMNR': 48, 'NBNS': 39, 'TLSv1': 27, 'DNS': 18, 'FTP': 8, 'BROWSER': 5, 'NTP': 2, 'SIP': 1}
# 2025-12-08 23:24:19,251 - root - INFO - Filtered packets ftp/ftps_down_1b.pcap: {'TCP': 1805557, 'TLSv1.2': 136081, 'UDP': 51, 'TLSv1': 27, 'DNS': 18, 'FTP': 8, 'BROWSER': 5, 'SIP': 1}
# 2025-12-08 23:24:19,311 - root - INFO - Processing file: ftps_up_2a.pcap
# 2025-12-08 23:24:21,907 - root - INFO - Original packets ftp/ftps_up_2a.pcap: {'TCP': 90463, 'TLSv1.2': 2648, 'BT-DHT': 213, 'TLSv1': 45, 'X11': 27, 'LLMNR': 8, 'ARP': 8, 'NBNS': 6, 'ICMPv6': 6, 'FTP': 6, 'IGMPv2': 2, 'UDP': 1}
# 2025-12-08 23:24:24,439 - root - INFO - Filtered packets ftp/ftps_up_2a.pcap: {'TCP': 90448, 'TLSv1.2': 2648, 'BT-DHT': 213, 'TLSv1': 45, 'X11': 15, 'FTP': 6, 'UDP': 1}
# 2025-12-08 23:24:24,440 - root - INFO - Processing file: vpn_ftps_A.pcap
# 2025-12-08 23:24:26,185 - root - INFO - Original packets ftp/vpn_ftps_A.pcap: {'TCP': 96186, 'TLSv1.2': 6245, 'SSLv3': 55, 'GQUIC': 44, 'FTP': 18, 'DNS': 12, 'TLSv1': 5, 'ICMP': 4}
# 2025-12-08 23:24:28,119 - root - INFO - Filtered packets ftp/vpn_ftps_A.pcap: {'TCP': 96186, 'TLSv1.2': 6245, 'SSLv3': 55, 'GQUIC': 44, 'FTP': 18, 'DNS': 12, 'TLSv1': 5}
# 2025-12-08 23:24:28,120 - root - INFO - Processing folder: voipbuster
# 2025-12-08 23:24:28,121 - root - INFO - Processing file: voipbuster_4a.pcap
# 2025-12-08 23:24:34,045 - root - INFO - Original packets voipbuster/voipbuster_4a.pcap: {'UDP': 368495, 'ARP': 731, 'LLMNR': 218, 'TCP': 201, 'NBNS': 165, 'TLSv1.2': 103, 'DNS': 74, 'HTTP': 24, 'NTP': 13, 'TLSv1': 8, 'THRIFT': 5, 'IGMPv2': 3, 'SSDP': 2, 'Chargen': 1}
# 2025-12-08 23:24:40,485 - root - INFO - Filtered packets voipbuster/voipbuster_4a.pcap: {'UDP': 368495, 'TCP': 201, 'TLSv1.2': 103, 'DNS': 74, 'HTTP': 24, 'TLSv1': 8}
# 2025-12-08 23:24:40,486 - root - INFO - Processing file: voipbuster2b.pcap
# 2025-12-08 23:24:41,276 - root - INFO - Original packets voipbuster/voipbuster2b.pcap: {'UDP': 33378, 'BT-DHT': 833, 'TCP': 213, 'ARP': 84, 'LLMNR': 32, 'NBNS': 24, 'DNS': 22, 'ICMPv6': 20, 'HTTP': 17, 'TLSv1.2': 12, 'SSDP': 6, 'IGMPv2': 6, 'ICMP': 6, 'LSD': 5, 'HTTP/XML': 5, 'NTP': 2, 'TLSv1': 1, 'BitTorrent': 1}
# 2025-12-08 23:24:42,033 - root - INFO - Filtered packets voipbuster/voipbuster2b.pcap: {'UDP': 33378, 'BT-DHT': 833, 'TCP': 213, 'DNS': 22, 'HTTP': 17, 'TLSv1.2': 12, 'HTTP/XML': 5, 'TLSv1': 1, 'BitTorrent': 1}
# 2025-12-08 23:24:42,033 - root - INFO - Processing file: voipbuster_4b.pcap
# 2025-12-08 23:24:47,963 - root - INFO - Original packets voipbuster/voipbuster_4b.pcap: {'UDP': 356182, 'SNMP': 6604, 'LLMNR': 3080, 'NBNS': 2323, 'ARP': 1025, 'TCP': 278, 'DNS': 122, 'TLSv1.2': 117, 'HTTP': 48, 'BROWSER': 13, 'NTP': 11, 'TLSv1': 9, 'THRIFT': 5, 'SSDP': 2, 'Chargen': 1}
# 2025-12-08 23:24:54,238 - root - INFO - Filtered packets voipbuster/voipbuster_4b.pcap: {'UDP': 356182, 'TCP': 278, 'DNS': 122, 'TLSv1.2': 117, 'HTTP': 48, 'BROWSER': 13, 'TLSv1': 9}
# 2025-12-08 23:24:54,239 - root - INFO - Processing file: voipbuster3b.pcap
# 2025-12-08 23:24:54,979 - root - INFO - Original packets voipbuster/voipbuster3b.pcap: {'UDP': 33509, 'BT-DHT': 805, 'ARP': 66, 'TCP': 46, 'LLMNR': 20, 'ICMPv6': 16, 'DNS': 16, 'NBNS': 15, 'IGMPv2': 6, 'ICMP': 5, 'LSD': 4, 'HTTP': 2}
# 2025-12-08 23:24:55,807 - root - INFO - Filtered packets voipbuster/voipbuster3b.pcap: {'UDP': 33509, 'BT-DHT': 805, 'TCP': 46, 'DNS': 16, 'HTTP': 2}
# 2025-12-08 23:24:55,808 - root - INFO - Processing file: vpn_voipbuster1b.pcap
# 2025-12-08 23:25:01,712 - root - INFO - Original packets voipbuster/vpn_voipbuster1b.pcap: {'UDP': 358957, 'LLMNR': 1712, 'TCP': 687, 'NBNS': 642, 'ARP': 407, 'TLSv1.2': 249, 'DNS': 241, 'DHCPv6': 65, 'THRIFT': 14, 'HTTP': 14, 'TLSv1': 11, 'NTP': 10, 'BROWSER': 9, 'IGMPv3': 6, 'ICMPv6': 6, 'ICMP': 6, 'LLDP': 3, 'DHCP': 2}
# 2025-12-08 23:25:07,699 - root - INFO - Filtered packets voipbuster/vpn_voipbuster1b.pcap: {'UDP': 358957, 'TCP': 687, 'TLSv1.2': 249, 'DNS': 241, 'HTTP': 14, 'TLSv1': 11, 'BROWSER': 9}
# 2025-12-08 23:25:07,700 - root - INFO - Processing file: voipbuster1b.pcap
# 2025-12-08 23:25:08,464 - root - INFO - Original packets voipbuster/voipbuster1b.pcap: {'UDP': 33641, 'BT-DHT': 980, 'TCP': 305, 'TLSv1.2': 172, 'GQUIC': 82, 'DNS': 70, 'ARP': 68, 'LLMNR': 48, 'NBNS': 39, 'ICMPv6': 21, 'TLSv1': 14, 'ICMP': 8, 'IGMPv2': 6, 'LSD': 5, 'HTTP': 4, 'NTP': 2, 'ENIP': 2, 'BitTorrent': 2}
# 2025-12-08 23:25:09,242 - root - INFO - Filtered packets voipbuster/voipbuster1b.pcap: {'UDP': 33641, 'BT-DHT': 980, 'TCP': 305, 'TLSv1.2': 172, 'GQUIC': 82, 'DNS': 70, 'TLSv1': 14, 'HTTP': 4, 'BitTorrent': 2}
# 2025-12-08 23:25:09,243 - root - INFO - Processing file: vpn_voipbuster1a.pcap
# 2025-12-08 23:25:15,007 - root - INFO - Original packets voipbuster/vpn_voipbuster1a.pcap: {'UDP': 357713, 'TCP': 1171, 'LLMNR': 1100, 'ARP': 513, 'NBNS': 414, 'TLSv1.2': 284, 'DNS': 153, 'DHCPv6': 63, 'HTTP': 17, 'THRIFT': 16, 'NTP': 12, 'TLSv1': 10, 'OCSP': 3}
# 2025-12-08 23:25:20,999 - root - INFO - Filtered packets voipbuster/vpn_voipbuster1a.pcap: {'UDP': 357713, 'TCP': 1171, 'TLSv1.2': 284, 'DNS': 153, 'HTTP': 17, 'TLSv1': 10}
# 2025-12-08 23:25:21,000 - root - INFO - Processing folder: sftp
# 2025-12-08 23:25:21,000 - root - INFO - Processing file: vpn_sftp_B.pcap
# 2025-12-08 23:25:21,586 - root - INFO - Original packets sftp/vpn_sftp_B.pcap: {'SSHv2': 11997, 'TCP': 6806, 'SSH': 1351, 'TLSv1.2': 11, 'GQUIC': 7, 'DNS': 3, 'TLSv1': 1, 'ICMP': 1}
# 2025-12-08 23:25:22,136 - root - INFO - Filtered packets sftp/vpn_sftp_B.pcap: {'SSHv2': 11997, 'TCP': 6806, 'SSH': 1351, 'TLSv1.2': 11, 'GQUIC': 7, 'DNS': 3, 'TLSv1': 1}
# 2025-12-08 23:25:22,137 - root - INFO - Processing file: sftp_down_3a.pcap
# 2025-12-08 23:25:23,906 - root - INFO - Original packets sftp/sftp_down_3a.pcap: {'SSHv2': 64495, 'TCP': 31352, 'SSH': 13, 'UDP': 4, 'ARP': 4}
# 2025-12-08 23:25:25,925 - root - INFO - Filtered packets sftp/sftp_down_3a.pcap: {'SSHv2': 64495, 'TCP': 31352, 'SSH': 13, 'UDP': 4}
# 2025-12-08 23:25:25,926 - root - INFO - Processing file: vpn_sftp_A.pcap
# 2025-12-08 23:25:27,498 - root - INFO - Original packets sftp/vpn_sftp_A.pcap: {'SSHv2': 58883, 'TCP': 31868, 'TLSv1.2': 92, 'GQUIC': 43, 'DNS': 9, 'SSH': 6, 'TLSv1': 2, 'ICMP': 2}
# 2025-12-08 23:25:29,065 - root - INFO - Filtered packets sftp/vpn_sftp_A.pcap: {'SSHv2': 58883, 'TCP': 31868, 'TLSv1.2': 92, 'GQUIC': 43, 'DNS': 9, 'SSH': 6, 'TLSv1': 2}
# 2025-12-08 23:25:29,065 - root - INFO - Processing file: sftp1.pcap
# 2025-12-08 23:25:34,921 - root - INFO - Original packets sftp/sftp1.pcap: {'TCP': 298779, 'TLSv1.2': 47465, 'SSDP': 39, 'TLSv1': 23, 'ICMP': 18, 'FTP': 12, 'BROWSER': 9, 'DHCPv6': 7, 'ARP': 4, 'DNS': 3, 'NBNS': 2}
# 2025-12-08 23:25:41,376 - root - INFO - Filtered packets sftp/sftp1.pcap: {'TCP': 298779, 'TLSv1.2': 47465, 'TLSv1': 23, 'FTP': 12, 'BROWSER': 9, 'DNS': 3}
# 2025-12-08 23:25:41,377 - root - INFO - Processing file: sftpDown1.pcap
# 2025-12-08 23:25:41,606 - root - INFO - Original packets sftp/sftpDown1.pcap: {'SSHv2': 1064, 'TCP': 822, 'TLSv1.2': 53, 'DNS': 36, 'ARP': 8, 'ICMP': 6, 'TLSv1': 2, 'SSH': 2, 'BROWSER': 2}
# 2025-12-08 23:25:41,908 - root - INFO - Filtered packets sftp/sftpDown1.pcap: {'SSHv2': 1064, 'TCP': 822, 'TLSv1.2': 53, 'DNS': 36, 'TLSv1': 2, 'SSH': 2, 'BROWSER': 2}
# 2025-12-08 23:25:41,909 - root - INFO - Processing file: sftp_up_2a.pcap
# 2025-12-08 23:25:43,871 - root - INFO - Original packets sftp/sftp_up_2a.pcap: {'SSH': 73335, 'TCP': 33826, 'SSL': 42, 'LLMNR': 16, 'NBNS': 12, 'ARP': 2, 'IGMPv2': 1}
# 2025-12-08 23:25:45,918 - root - INFO - Filtered packets sftp/sftp_up_2a.pcap: {'SSH': 73335, 'TCP': 33826, 'SSL': 42}
# 2025-12-08 23:25:45,919 - root - INFO - Processing file: sftpDown2.pcap
# 2025-12-08 23:25:46,273 - root - INFO - Original packets sftp/sftpDown2.pcap: {'SSHv2': 2689, 'TCP': 1974, 'DNS': 44, 'ARP': 8, 'TLSv1.2': 4, 'SSH': 4, 'NBNS': 2, 'ICMP': 2, 'BROWSER': 2}
# 2025-12-08 23:25:46,629 - root - INFO - Filtered packets sftp/sftpDown2.pcap: {'SSHv2': 2689, 'TCP': 1974, 'DNS': 44, 'TLSv1.2': 4, 'SSH': 4, 'BROWSER': 2}
# 2025-12-08 23:25:46,630 - root - INFO - Processing file: sftp_up_2b.pcap
# 2025-12-08 23:25:48,301 - root - INFO - Original packets sftp/sftp_up_2b.pcap: {'SSHv2': 64338, 'TCP': 31331, 'SNMP': 32, 'LLMNR': 28, 'NBNS': 21, 'SSH': 13, 'UDP': 12, 'ARP': 10}
# 2025-12-08 23:25:50,082 - root - INFO - Filtered packets sftp/sftp_up_2b.pcap: {'SSHv2': 64338, 'TCP': 31331, 'SSH': 13, 'UDP': 12}
# 2025-12-08 23:25:50,083 - root - INFO - Processing file: sftp_down_3b.pcap
# 2025-12-08 23:25:51,036 - root - INFO - Original packets sftp/sftp_down_3b.pcap: {'TCP': 33777, 'SSH': 14733, 'SNMP': 954, 'LLMNR': 20, 'NBNS': 16, 'DNS': 14, 'ARP': 12}
# 2025-12-08 23:25:52,095 - root - INFO - Filtered packets sftp/sftp_down_3b.pcap: {'TCP': 33777, 'SSH': 14733, 'DNS': 14}
# 2025-12-08 23:25:52,096 - root - INFO - Processing file: sftpUp1.pcap
# 2025-12-08 23:25:53,272 - root - INFO - Original packets sftp/sftpUp1.pcap: {'TCP': 33929, 'SSHv2': 28989, 'DNS': 26, 'ARP': 12, 'BROWSER': 4, 'SSH': 2, 'NBNS': 2, 'ICMP': 2}
# 2025-12-08 23:25:54,546 - root - INFO - Filtered packets sftp/sftpUp1.pcap: {'TCP': 33929, 'SSHv2': 28989, 'DNS': 26, 'BROWSER': 4, 'SSH': 2}
# 2025-12-08 23:25:54,547 - root - INFO - Processing folder: vimeo
# 2025-12-08 23:25:54,548 - root - INFO - Processing file: vimeo3.pcap
# 2025-12-08 23:25:55,358 - root - INFO - Original packets vimeo/vimeo3.pcap: {'TCP': 24119, 'SSLv2': 6995, 'TLSv1.2': 384, 'SSL': 250, 'DNS': 80, 'TLSv1': 37, 'ICMP': 20, 'ARP': 8, 'BROWSER': 5, 'NBNS': 4, 'MDNS': 1}
# 2025-12-08 23:25:56,482 - root - INFO - Filtered packets vimeo/vimeo3.pcap: {'TCP': 24119, 'SSLv2': 6995, 'TLSv1.2': 379, 'SSL': 250, 'DNS': 80, 'TLSv1': 37, 'BROWSER': 5}
# 2025-12-08 23:25:56,483 - root - INFO - Processing file: vimeo2.pcap
# 2025-12-08 23:25:56,813 - root - INFO - Original packets vimeo/vimeo2.pcap: {'TCP': 2062, 'TLSv1.2': 885, 'TLSv1': 44, 'DNS': 40, 'ICMP': 5, 'ARP': 2}
# 2025-12-08 23:25:57,102 - root - INFO - Filtered packets vimeo/vimeo2.pcap: {'TCP': 2062, 'TLSv1.2': 881, 'TLSv1': 44, 'DNS': 40}
# 2025-12-08 23:25:57,102 - root - INFO - Processing file: vimeo4.pcap
# 2025-12-08 23:25:57,727 - root - INFO - Original packets vimeo/vimeo4.pcap: {'TCP': 10791, 'TLSv1.2': 7753, 'DNS': 82, 'TLSv1': 72, 'SMB2': 23, 'ICMP': 18, 'ARP': 6, 'BROWSER': 3, 'SPOOLSS': 2, 'NBNS': 2, 'DCERPC': 2, 'SMB': 1}
# 2025-12-08 23:25:58,419 - root - INFO - Filtered packets vimeo/vimeo4.pcap: {'TCP': 10791, 'TLSv1.2': 7741, 'DNS': 82, 'TLSv1': 72, 'SMB2': 23, 'BROWSER': 3, 'SMB': 1}
# 2025-12-08 23:25:58,420 - root - INFO - Processing file: vimeo1.pcap
# 2025-12-08 23:26:00,729 - root - INFO - Original packets vimeo/vimeo1.pcap: {'TCP': 61227, 'TLSv1.2': 31271, 'DNS': 76, 'TLSv1': 48, 'ICMP': 36, 'SMB2': 21, 'ARP': 10, 'BROWSER': 7, 'NBNS': 4, 'SPOOLSS': 2, 'DCERPC': 2, 'SMB': 1}
# 2025-12-08 23:26:03,123 - root - INFO - Filtered packets vimeo/vimeo1.pcap: {'TCP': 61227, 'TLSv1.2': 31259, 'DNS': 76, 'TLSv1': 48, 'SMB2': 21, 'BROWSER': 7, 'SMB': 1}
# 2025-12-08 23:26:03,124 - root - INFO - Processing file: vpn_vimeo_A.pcap
# 2025-12-08 23:26:05,005 - root - INFO - Original packets vimeo/vpn_vimeo_A.pcap: {'TCP': 78002, 'TLSv1.2': 26635, 'TLSv1': 79, 'GQUIC': 62, 'DB-LSP-DISC/JSON': 45, 'UDP': 23, 'DNS': 21, 'ICMP': 7}
# 2025-12-08 23:26:06,988 - root - INFO - Filtered packets vimeo/vpn_vimeo_A.pcap: {'TCP': 78002, 'TLSv1.2': 26629, 'TLSv1': 79, 'GQUIC': 62, 'UDP': 23, 'DNS': 21}
# 2025-12-08 23:26:06,989 - root - INFO - Processing file: vpn_vimeo_B.pcap
# 2025-12-08 23:26:10,592 - root - INFO - Original packets vimeo/vpn_vimeo_B.pcap: {'TCP': 142229, 'TLSv1.2': 72684, 'TLSv1': 61, 'GQUIC': 47, 'DB-LSP-DISC/JSON': 32, 'UDP': 23, 'DNS': 18, 'ICMP': 6, 'SSLv2': 2}
# 2025-12-08 23:26:14,585 - root - INFO - Filtered packets vimeo/vpn_vimeo_B.pcap: {'TCP': 142229, 'TLSv1.2': 72683, 'TLSv1': 61, 'GQUIC': 47, 'UDP': 23, 'DNS': 18, 'SSLv2': 2}
# 2025-12-08 23:26:14,586 - root - INFO - Processing folder: torrent
# 2025-12-08 23:26:14,586 - root - INFO - Processing file: vpn_bittorrent.pcap
# 2025-12-08 23:26:23,343 - root - INFO - Original packets torrent/vpn_bittorrent.pcap: {'TCP': 411339, 'UDP': 6197, 'HTTP': 3873, 'BT-DHT': 309, 'DNS': 224, 'TLSv1.2': 100, 'ICMP': 24, 'NAT-PMP': 9, 'SSLv3': 8, 'HTTP/XML': 8, 'SSDP': 4, 'NTP': 2, 'HTTP/JSON': 1}
# 2025-12-08 23:26:32,878 - root - INFO - Filtered packets torrent/vpn_bittorrent.pcap: {'TCP': 411332, 'UDP': 6197, 'HTTP': 3873, 'BT-DHT': 309, 'DNS': 224, 'TLSv1.2': 99, 'SSLv3': 8, 'HTTP/XML': 8, 'HTTP/JSON': 1}
# 2025-12-08 23:26:32,879 - root - INFO - Processing folder: youtube
# 2025-12-08 23:26:32,879 - root - INFO - Processing file: youtube6.pcap
# 2025-12-08 23:26:33,287 - root - INFO - Original packets youtube/youtube6.pcap: {'TCP': 4899, 'TLSv1.2': 2961, 'DNS': 68, 'TLSv1': 4, 'IGMPv3': 4, 'ICMP': 4, 'SSDP': 3, 'NBNS': 2, 'ARP': 2, 'BROWSER': 1}
# 2025-12-08 23:26:33,697 - root - INFO - Filtered packets youtube/youtube6.pcap: {'TCP': 4899, 'TLSv1.2': 2961, 'DNS': 68, 'TLSv1': 4, 'BROWSER': 1}
# 2025-12-08 23:26:33,698 - root - INFO - Processing file: youtubeHTML5_1.pcap
# 2025-12-08 23:26:34,803 - root - INFO - Original packets youtube/youtubeHTML5_1.pcap: {'TCP': 30496, 'TLSv1.2': 10592, 'DNS': 72, 'TLSv1': 54, 'ICMP': 47, 'SMB2': 44, 'HTTP': 31, 'ARP': 18, 'BROWSER': 9, 'NBNS': 6, 'SPOOLSS': 4, 'DCERPC': 4, 'SMB': 2, 'MDNS': 1}
# 2025-12-08 23:26:36,013 - root - INFO - Filtered packets youtube/youtubeHTML5_1.pcap: {'TCP': 30496, 'TLSv1.2': 10592, 'DNS': 72, 'TLSv1': 54, 'SMB2': 44, 'HTTP': 31, 'BROWSER': 9, 'SMB': 2}
# 2025-12-08 23:26:36,014 - root - INFO - Processing file: youtube3.pcap
# 2025-12-08 23:26:36,403 - root - INFO - Original packets youtube/youtube3.pcap: {'TCP': 4524, 'TLSv1.2': 2631, 'DNS': 68, 'SMB2': 23, 'ICMP': 16, 'TLSv1': 5, 'IGMPv3': 4, 'ARP': 4, 'SSDP': 3, 'BROWSER': 3, 'SPOOLSS': 2, 'OCSP': 2, 'DCERPC': 2, 'SMB': 1}
# 2025-12-08 23:26:36,744 - root - INFO - Filtered packets youtube/youtube3.pcap: {'TCP': 4524, 'TLSv1.2': 2631, 'DNS': 68, 'SMB2': 23, 'TLSv1': 5, 'BROWSER': 3, 'SMB': 1}
# 2025-12-08 23:26:36,746 - root - INFO - Processing file: youtube5.pcap
# 2025-12-08 23:26:39,621 - root - INFO - Original packets youtube/youtube5.pcap: {'TCP': 96798, 'TLSv1.2': 38014, 'DNS': 162, 'TLSv1': 30, 'ICMP': 25, 'IGMPv3': 20, 'SSDP': 15, 'BROWSER': 8, 'ARP': 8, 'NBNS': 4, 'OCSP': 2, 'UDP': 1}
# 2025-12-08 23:26:42,480 - root - INFO - Filtered packets youtube/youtube5.pcap: {'TCP': 96798, 'TLSv1.2': 38014, 'DNS': 162, 'TLSv1': 30, 'BROWSER': 8, 'UDP': 1}
# 2025-12-08 23:26:42,481 - root - INFO - Processing file: youtube2.pcap
# 2025-12-08 23:26:42,959 - root - INFO - Original packets youtube/youtube2.pcap: {'TCP': 8457, 'TLSv1.2': 4196, 'DNS': 64, 'TLSv1': 10, 'ICMP': 7, 'OCSP': 4}
# 2025-12-08 23:26:43,451 - root - INFO - Filtered packets youtube/youtube2.pcap: {'TCP': 8457, 'TLSv1.2': 4196, 'DNS': 64, 'TLSv1': 10}
# 2025-12-08 23:26:43,452 - root - INFO - Processing file: vpn_youtube_A.pcap
# 2025-12-08 23:26:46,744 - root - INFO - Original packets youtube/vpn_youtube_A.pcap: {'TCP': 191608, 'TLSv1.2': 14921, 'GQUIC': 1309, 'TLSv1': 222, 'UDP': 129, 'DB-LSP-DISC/JSON': 89, 'DNS': 57, 'ICMP': 19, 'SSLv2': 1}
# 2025-12-08 23:26:50,202 - root - INFO - Filtered packets youtube/vpn_youtube_A.pcap: {'TCP': 191608, 'TLSv1.2': 14921, 'GQUIC': 1309, 'TLSv1': 222, 'UDP': 129, 'DNS': 57, 'SSLv2': 1}
# 2025-12-08 23:26:50,203 - root - INFO - Processing file: youtube4.pcap
# 2025-12-08 23:26:51,233 - root - INFO - Original packets youtube/youtube4.pcap: {'TCP': 26158, 'TLSv1.2': 13341, 'DNS': 148, 'ICMP': 36, 'TLSv1': 15, 'IGMPv3': 12, 'SSDP': 9, 'ARP': 6, 'BROWSER': 5, 'SMB2': 4, 'OCSP': 4, 'NBNS': 4}
# 2025-12-08 23:26:52,466 - root - INFO - Filtered packets youtube/youtube4.pcap: {'TCP': 26158, 'TLSv1.2': 13341, 'DNS': 148, 'TLSv1': 15, 'BROWSER': 5, 'SMB2': 4}
# 2025-12-08 23:26:52,467 - root - INFO - Processing file: youtube1.pcap
# 2025-12-08 23:26:52,819 - root - INFO - Original packets youtube/youtube1.pcap: {'TCP': 4545, 'TLSv1.2': 3116, 'DNS': 192, 'TLSv1': 20, 'ICMP': 18, 'IGMPv3': 12, 'SSDP': 9, 'OCSP': 8, 'ARP': 6, 'BROWSER': 3, 'NBNS': 2, 'MDNS': 1}
# 2025-12-08 23:26:53,255 - root - INFO - Filtered packets youtube/youtube1.pcap: {'TCP': 4545, 'TLSv1.2': 3114, 'DNS': 192, 'TLSv1': 20, 'BROWSER': 3}
# 2025-12-08 23:26:53,256 - root - INFO - Processing folder: hangout
# 2025-12-08 23:26:53,256 - root - INFO - Processing file: vpn_hangouts_audio1.pcap
# 2025-12-08 23:26:59,442 - root - INFO - Original packets hangout/vpn_hangouts_audio1.pcap: {'UDP': 386111, 'TLSv1.2': 21226, 'TCP': 17208, 'STUN': 15673, 'DNS': 6132, 'ICMP': 193, 'TLSv1': 124, 'OCSP': 2}
# 2025-12-08 23:27:05,722 - root - INFO - Filtered packets hangout/vpn_hangouts_audio1.pcap: {'UDP': 386111, 'TLSv1.2': 21226, 'TCP': 17208, 'DNS': 6132, 'TLSv1': 124}
# 2025-12-08 23:27:05,723 - root - INFO - Processing file: hangouts_chat_4a.pcap
# 2025-12-08 23:27:06,053 - root - INFO - Original packets hangout/hangouts_chat_4a.pcap: {'UDP': 3982, 'GQUIC': 1003, 'TCP': 319, 'TLSv1.2': 184, 'LLMNR': 54, 'NBNS': 41, 'HTTP': 38, 'DNS': 36, 'TLSv1': 9, 'ARP': 6, 'NTP': 2, 'SSDP': 1}
# 2025-12-08 23:27:06,340 - root - INFO - Filtered packets hangout/hangouts_chat_4a.pcap: {'UDP': 3982, 'GQUIC': 1003, 'TCP': 319, 'TLSv1.2': 184, 'HTTP': 38, 'DNS': 36, 'TLSv1': 9}
# 2025-12-08 23:27:06,341 - root - INFO - Processing file: vpn_hangouts_chat1a.pcap
# 2025-12-08 23:27:07,006 - root - INFO - Original packets hangout/vpn_hangouts_chat1a.pcap: {'TLSv1.2': 13359, 'TCP': 11495, 'DNS': 2456, 'TLSv1': 51, 'ICMP': 29, 'OCSP': 14, 'HTTP': 4}
# 2025-12-08 23:27:07,688 - root - INFO - Filtered packets hangout/vpn_hangouts_chat1a.pcap: {'TLSv1.2': 13359, 'TCP': 11495, 'DNS': 2456, 'TLSv1': 51, 'HTTP': 4}
# 2025-12-08 23:27:07,689 - root - INFO - Processing file: hangouts_audio2b.pcap
# 2025-12-08 23:27:09,077 - root - INFO - Original packets hangout/hangouts_audio2b.pcap: {'UDP': 63951, 'TLSv1.2': 4419, 'STUN': 3622, 'TCP': 2897, 'DNS': 38, 'ARP': 22, 'LLMNR': 20, 'TLSv1': 17, 'NBNS': 15, 'GQUIC': 7}
# 2025-12-08 23:27:10,446 - root - INFO - Filtered packets hangout/hangouts_audio2b.pcap: {'UDP': 63951, 'TLSv1.2': 4419, 'TCP': 2897, 'DNS': 38, 'TLSv1': 17, 'GQUIC': 7}
# 2025-12-08 23:27:10,447 - root - INFO - Processing file: hangouts_audio1b.pcap
# 2025-12-08 23:27:11,907 - root - INFO - Original packets hangout/hangouts_audio1b.pcap: {'UDP': 70577, 'TLSv1.2': 4548, 'STUN': 3924, 'TCP': 3188, 'DNS': 38, 'HTTP': 26, 'GQUIC': 25, 'ARP': 22, 'LLMNR': 20, 'NBNS': 15, 'TLSv1': 10}
# 2025-12-08 23:27:13,365 - root - INFO - Filtered packets hangout/hangouts_audio1b.pcap: {'UDP': 70577, 'TLSv1.2': 4548, 'TCP': 3188, 'DNS': 38, 'HTTP': 26, 'GQUIC': 25, 'TLSv1': 10}
# 2025-12-08 23:27:13,366 - root - INFO - Processing file: hangouts_video2a.pcap
# 2025-12-08 23:27:27,068 - root - INFO - Original packets hangout/hangouts_video2a.pcap: {'UDP': 783710, 'TLSv1.2': 8453, 'TCP': 6888, 'STUN': 6116, 'DNS': 2595, 'ICMP': 137, 'SMB2': 86, 'SMB': 66, 'GQUIC': 53, 'IGMPv3': 48, 'TLSv1': 47, 'SSDP': 36, 'ARP': 34, 'NBSS': 20, 'LANMAN': 20, 'BROWSER': 19, 'NBNS': 12, 'SPOOLSS': 2, 'DCERPC': 2}
# 2025-12-08 23:27:41,553 - root - INFO - Filtered packets hangout/hangouts_video2a.pcap: {'UDP': 783710, 'TLSv1.2': 8453, 'TCP': 6888, 'DNS': 2595, 'SMB2': 86, 'SMB': 66, 'GQUIC': 53, 'TLSv1': 47, 'NBSS': 20, 'BROWSER': 19}
# 2025-12-08 23:27:41,554 - root - INFO - Processing file: hangouts_audio2a.pcap
# 2025-12-08 23:27:43,155 - root - INFO - Original packets hangout/hangouts_audio2a.pcap: {'UDP': 69115, 'TLSv1.2': 5693, 'TCP': 4613, 'STUN': 3982, 'DNS': 1619, 'ICMP': 78, 'GQUIC': 37, 'TLSv1': 28, 'IGMPv3': 28, 'SSDP': 21, 'ARP': 14, 'SMB2': 13, 'SMB': 13, 'BROWSER': 12, 'NBNS': 7, 'NBSS': 4, 'LANMAN': 4}
# 2025-12-08 23:27:44,741 - root - INFO - Filtered packets hangout/hangouts_audio2a.pcap: {'UDP': 69115, 'TLSv1.2': 5693, 'TCP': 4613, 'DNS': 1619, 'GQUIC': 37, 'TLSv1': 28, 'SMB2': 13, 'SMB': 13, 'BROWSER': 12, 'NBSS': 4}
# 2025-12-08 23:27:44,741 - root - INFO - Processing file: hangouts_audio4.pcap
# 2025-12-08 23:28:00,005 - root - INFO - Original packets hangout/hangouts_audio4.pcap: {'UDP': 574181, 'LLMNR': 168230, 'ARP': 99377, 'NBNS': 77020, 'TLSv1.2': 26411, 'STUN': 23499, 'TCP': 19793, 'DNS': 8494, 'MDNS': 5400, 'DB-LSP-DISC/JSON': 4104, 'DHCPv6': 3319, 'ICMPv6': 3028, 'SSDP': 1616, 'BROWSER': 1074, 'STP': 1031, 'IGMPv2': 682, 'ICMP': 671, 'NTP': 600, 'IPX SAP': 344, 'LLDP': 172, 'IGMPv3': 117, 'DHCP': 116, 'TLSv1': 89, 'SRVLOC': 47, 'LLC': 39}
# 2025-12-08 23:28:10,736 - root - INFO - Filtered packets hangout/hangouts_audio4.pcap: {'UDP': 574181, 'TLSv1.2': 26411, 'TCP': 19793, 'DNS': 8494, 'BROWSER': 1074, 'TLSv1': 89}
# 2025-12-08 23:28:10,737 - root - INFO - Processing file: hangouts_audio1a.pcap
# 2025-12-08 23:28:12,325 - root - INFO - Original packets hangout/hangouts_audio1a.pcap: {'UDP': 71529, 'TLSv1.2': 5325, 'TCP': 4325, 'STUN': 4276, 'DNS': 1684, 'ICMP': 68, 'IGMPv3': 32, 'SSDP': 24, 'TLSv1': 20, 'BROWSER': 16, 'GQUIC': 14, 'ARP': 14, 'NBNS': 6, 'MDNS': 1}
# 2025-12-08 23:28:13,916 - root - INFO - Filtered packets hangout/hangouts_audio1a.pcap: {'UDP': 71529, 'TLSv1.2': 5325, 'TCP': 4325, 'DNS': 1684, 'TLSv1': 20, 'BROWSER': 16, 'GQUIC': 14}
# 2025-12-08 23:28:13,917 - root - INFO - Processing file: hangouts_video1b.pcap
# 2025-12-08 23:28:21,188 - root - INFO - Original packets hangout/hangouts_video1b.pcap: {'UDP': 426108, 'TLSv1.2': 6121, 'TCP': 3771, 'STUN': 3322, 'DNS': 34, 'ARP': 26, 'LLMNR': 8, 'NBNS': 6, 'TLSv1': 5, 'SSDP': 1}
# 2025-12-08 23:28:29,079 - root - INFO - Filtered packets hangout/hangouts_video1b.pcap: {'UDP': 426108, 'TLSv1.2': 6121, 'TCP': 3771, 'DNS': 34, 'TLSv1': 5}
# 2025-12-08 23:28:29,080 - root - INFO - Processing file: vpn_hangouts_audio2.pcap
# 2025-12-08 23:28:36,300 - root - INFO - Original packets hangout/vpn_hangouts_audio2.pcap: {'UDP': 398729, 'TCP': 27121, 'TLSv1.2': 25803, 'STUN': 17196, 'DNS': 9743, 'ICMP': 269, 'TLSv1': 116, 'HTTP': 43, 'OCSP': 20, 'TLSv1.1': 16, 'SSLv3': 4, 'HTTP/JSON': 3}
# 2025-12-08 23:28:43,378 - root - INFO - Filtered packets hangout/vpn_hangouts_audio2.pcap: {'UDP': 398729, 'TCP': 27121, 'TLSv1.2': 25802, 'DNS': 9743, 'TLSv1': 116, 'HTTP': 43, 'TLSv1.1': 16, 'SSLv3': 4, 'HTTP/JSON': 3}
# 2025-12-08 23:28:43,379 - root - INFO - Processing file: hangouts_video2b.pcap
# 2025-12-08 23:28:55,536 - root - INFO - Original packets hangout/hangouts_video2b.pcap: {'UDP': 727148, 'TLSv1.2': 6133, 'STUN': 5533, 'TCP': 3984, 'DNS': 60, 'LLMNR': 32, 'ARP': 32, 'NBNS': 24, 'GQUIC': 22, 'TLSv1': 13, 'HTTP': 6, 'SSLv2': 1}
# 2025-12-08 23:29:09,385 - root - INFO - Filtered packets hangout/hangouts_video2b.pcap: {'UDP': 727148, 'TLSv1.2': 6133, 'TCP': 3984, 'DNS': 60, 'GQUIC': 22, 'TLSv1': 13, 'HTTP': 6, 'SSLv2': 1}
# 2025-12-08 23:29:09,386 - root - INFO - Processing file: vpn_hangouts_chat1b.pcap
# 2025-12-08 23:29:09,904 - root - INFO - Original packets hangout/vpn_hangouts_chat1b.pcap: {'TLSv1.2': 7489, 'TCP': 7090, 'DNS': 2910, 'ICMP': 29, 'TLSv1': 23, 'NTP': 2}
# 2025-12-08 23:29:10,426 - root - INFO - Filtered packets hangout/vpn_hangouts_chat1b.pcap: {'TLSv1.2': 7489, 'TCP': 7090, 'DNS': 2910, 'TLSv1': 23}
# 2025-12-08 23:29:10,427 - root - INFO - Processing file: hangout_chat_4b.pcap
# 2025-12-08 23:29:10,762 - root - INFO - Original packets hangout/hangout_chat_4b.pcap: {'UDP': 3190, 'SNMP': 2068, 'GQUIC': 982, 'LLMNR': 580, 'NBNS': 443, 'TCP': 140, 'TLSv1.2': 93, 'ARP': 54, 'DNS': 28, 'BROWSER': 5, 'TLSv1': 4}
# 2025-12-08 23:29:11,037 - root - INFO - Filtered packets hangout/hangout_chat_4b.pcap: {'UDP': 3190, 'GQUIC': 982, 'TCP': 140, 'TLSv1.2': 93, 'DNS': 28, 'BROWSER': 5, 'TLSv1': 4}
# 2025-12-08 23:29:11,038 - root - INFO - Processing file: hangouts_audio3.pcap
# 2025-12-08 23:29:20,665 - root - INFO - Original packets hangout/hangouts_audio3.pcap: {'UDP': 555864, 'STUN': 21258, 'TLSv1.2': 16456, 'TCP': 14430, 'ICMP': 556, 'SSDP': 447, 'BROWSER': 144, 'DNS': 142, 'DHCPv6': 96, 'ARP': 74, 'LLMNR': 72, 'NBNS': 65, 'GQUIC': 44, 'TLSv1': 38, 'HTTP': 18, 'HTTP/XML': 9, 'LLDP': 6, 'HTTP/JSON': 1}
# 2025-12-08 23:29:30,692 - root - INFO - Filtered packets hangout/hangouts_audio3.pcap: {'UDP': 555864, 'TLSv1.2': 16455, 'TCP': 14430, 'BROWSER': 144, 'DNS': 142, 'GQUIC': 44, 'TLSv1': 38, 'HTTP': 18, 'HTTP/XML': 9, 'HTTP/JSON': 1}
# 2025-12-08 23:29:30,693 - root - INFO - Processing folder: icq
# 2025-12-08 23:29:30,694 - root - INFO - Processing file: vpn_icq_chat1b.pcap
# 2025-12-08 23:29:30,929 - root - INFO - Original packets icq/vpn_icq_chat1b.pcap: {'SSL': 2007, 'TCP': 1674}
# 2025-12-08 23:29:31,165 - root - INFO - Filtered packets icq/vpn_icq_chat1b.pcap: {'SSL': 2007, 'TCP': 1674}
# 2025-12-08 23:29:31,166 - root - INFO - Processing file: vpn_icq_chat1a.pcap
# 2025-12-08 23:29:31,413 - root - INFO - Original packets icq/vpn_icq_chat1a.pcap: {'SSL': 2167, 'TCP': 1933, 'UDP': 66, 'TLSv1': 22, 'DNS': 6, 'NTP': 2}
# 2025-12-08 23:29:31,725 - root - INFO - Filtered packets icq/vpn_icq_chat1a.pcap: {'SSL': 2167, 'TCP': 1933, 'UDP': 66, 'TLSv1': 22, 'DNS': 6}
# 2025-12-08 23:29:31,727 - root - INFO - Processing file: ICQchat2.pcap
# 2025-12-08 23:29:31,925 - root - INFO - Original packets icq/ICQchat2.pcap: {'TCP': 103, 'SSL': 67, 'LLMNR': 28, 'NBNS': 21, 'TLSv1.2': 17, 'DNS': 12, 'TLSv1': 10, 'TLSv1.1': 8, 'ARP': 8, 'UDP': 4, 'NTP': 2}
# 2025-12-08 23:29:32,137 - root - INFO - Filtered packets icq/ICQchat2.pcap: {'TCP': 103, 'SSL': 67, 'TLSv1.2': 17, 'DNS': 12, 'TLSv1': 10, 'TLSv1.1': 8, 'UDP': 4}
# 2025-12-08 23:29:32,138 - root - INFO - Processing file: icq_chat_3b.pcap
# 2025-12-08 23:29:32,423 - root - INFO - Original packets icq/icq_chat_3b.pcap: {'SNMP': 1126, 'LLMNR': 572, 'NBNS': 430, 'TCP': 233, 'SSL': 208, 'ARP': 70, 'TLSv1': 48, 'TLSv1.2': 24, 'DNS': 8, 'IGMPv2': 1, 'BROWSER': 1}
# 2025-12-08 23:29:32,609 - root - INFO - Filtered packets icq/icq_chat_3b.pcap: {'TCP': 233, 'SSL': 208, 'TLSv1': 48, 'TLSv1.2': 24, 'DNS': 8, 'BROWSER': 1}
# 2025-12-08 23:29:32,610 - root - INFO - Processing file: icq_chat_3a.pcap
# 2025-12-08 23:29:32,801 - root - INFO - Original packets icq/icq_chat_3a.pcap: {'TCP': 288, 'SSL': 196, 'TLSv1.2': 67, 'LLMNR': 66, 'NBNS': 51, 'TLSv1': 27, 'ARP': 24, 'DNS': 18, 'UDP': 12, 'NTP': 4, 'HTTP': 2}
# 2025-12-08 23:29:33,005 - root - INFO - Filtered packets icq/icq_chat_3a.pcap: {'TCP': 288, 'SSL': 196, 'TLSv1.2': 67, 'TLSv1': 27, 'DNS': 18, 'UDP': 12, 'HTTP': 2}
# 2025-12-08 23:29:33,006 - root - INFO - Processing file: ICQchat1.pcap
# 2025-12-08 23:29:33,204 - root - INFO - Original packets icq/ICQchat1.pcap: {'TCP': 187, 'SSL': 127, 'LLMNR': 48, 'NBNS': 36, 'TLSv1': 27, 'ARP': 22, 'TLSv1.2': 15, 'TLSv1.1': 13, 'DNS': 6, 'UDP': 4, 'NTP': 2}
# 2025-12-08 23:29:33,398 - root - INFO - Filtered packets icq/ICQchat1.pcap: {'TCP': 187, 'SSL': 127, 'TLSv1': 27, 'TLSv1.2': 15, 'TLSv1.1': 13, 'DNS': 6, 'UDP': 4}
# 2025-12-08 23:29:33,399 - root - INFO - Processing folder: scp
# 2025-12-08 23:29:33,399 - root - INFO - Processing file: scp1.pcap
# ...
# 2025-12-08 23:30:35,205 - root - INFO - Filtered packets aim/vpn_aim_chat1a.pcap: {'TCP': 571, 'TLSv1': 563, 'UDP': 28, 'DNS': 6}
# 2025-12-08 23:30:35,206 - root - INFO - Processing file: AIMchat1.pcap
# 2025-12-08 23:30:35,401 - root - INFO - Original packets aim/AIMchat1.pcap: {'TCP': 155, 'TLSv1.2': 59, 'SSL': 52, 'TLSv1.1': 44, 'LLMNR': 28, 'NBNS': 21, 'ARP': 20, 'TLSv1': 13, 'UDP': 8, 'NTP': 2, 'DNS': 2}
# 2025-12-08 23:30:35,599 - root - INFO - Filtered packets aim/AIMchat1.pcap: {'TCP': 155, 'TLSv1.2': 59, 'SSL': 52, 'TLSv1.1': 44, 'TLSv1': 13, 'UDP': 8, 'DNS': 2}
# 2025-12-08 23:30:35,600 - root - INFO - Processing file: vpn_aim_chat1b.pcap
# 2025-12-08 23:30:35,811 - root - INFO - Original packets aim/vpn_aim_chat1b.pcap: {'TLSv1': 641, 'TCP': 569, 'SSL': 68, 'DNS': 6, 'NTP': 2, 'ICMP': 1}
# 2025-12-08 23:30:36,023 - root - INFO - Filtered packets aim/vpn_aim_chat1b.pcap: {'TLSv1': 641, 'TCP': 569, 'SSL': 68, 'DNS': 6}
# 2025-12-08 23:30:36,024 - root - INFO - Processing file: aim_chat_3a.pcap
# 2025-12-08 23:30:36,233 - root - INFO - Original packets aim/aim_chat_3a.pcap: {'TCP': 754, 'TLSv1.2': 329, 'SSL': 48, 'LLMNR': 40, 'NBNS': 30, 'ARP': 18, 'UDP': 8, 'TLSv1': 8, 'DNS': 6, 'NTP': 2}
# 2025-12-08 23:30:36,432 - root - INFO - Filtered packets aim/aim_chat_3a.pcap: {'TCP': 754, 'TLSv1.2': 329, 'SSL': 48, 'UDP': 8, 'TLSv1': 8, 'DNS': 6}
# 2025-12-08 23:30:36,433 - root - INFO - Processing file: AIMchat2.pcap
# 2025-12-08 23:30:36,627 - root - INFO - Original packets aim/AIMchat2.pcap: {'TCP': 143, 'TLSv1.2': 63, 'TLSv1.1': 54, 'SSL': 33, 'LLMNR': 28, 'NBNS': 21, 'ARP': 8, 'DNS': 6, 'UDP': 4, 'TLSv1': 4, 'NTP': 2}
# 2025-12-08 23:30:36,824 - root - INFO - Filtered packets aim/AIMchat2.pcap: {'TCP': 143, 'TLSv1.2': 63, 'TLSv1.1': 54, 'SSL': 33, 'DNS': 6, 'UDP': 4, 'TLSv1': 4}
# 2025-12-08 23:30:36,825 - root - INFO - Processing folder: email
# 2025-12-08 23:30:36,826 - root - INFO - Processing file: vpn_email2b.pcap
# 2025-12-08 23:30:37,373 - root - INFO - Original packets email/vpn_email2b.pcap: {'TCP': 9796, 'TLSv1.2': 8841, 'DNS': 150, 'TLSv1': 65, 'OCSP': 12, 'ICMP': 10}
# 2025-12-08 23:30:37,840 - root - INFO - Filtered packets email/vpn_email2b.pcap: {'TCP': 9796, 'TLSv1.2': 8841, 'DNS': 150, 'TLSv1': 65}
# 2025-12-08 23:30:37,841 - root - INFO - Processing file: email2a.pcap
# 2025-12-08 23:30:38,113 - root - INFO - Original packets email/email2a.pcap: {'TCP': 2284, 'TLSv1.2': 1284, 'UDP': 461, 'DNS': 182, 'TLSv1': 108, 'ARP': 62, 'ICMP': 28, 'NTP': 4, 'OCSP': 2, 'MDNS': 2}
# 2025-12-08 23:30:38,375 - root - INFO - Filtered packets email/email2a.pcap: {'TCP': 2284, 'TLSv1.2': 1284, 'UDP': 461, 'DNS': 182, 'TLSv1': 108}
# 2025-12-08 23:30:38,376 - root - INFO - Processing file: email2b.pcap
# 2025-12-08 23:30:38,700 - root - INFO - Original packets email/email2b.pcap: {'TCP': 3808, 'TLSv1.2': 3163, 'UDP': 384, 'DNS': 122, 'TLSv1': 110, 'ARP': 70, 'ICMP': 17, 'NTP': 6, 'MDNS': 4, 'HTTP': 2}
# 2025-12-08 23:30:39,020 - root - INFO - Filtered packets email/email2b.pcap: {'TCP': 3808, 'TLSv1.2': 3163, 'UDP': 384, 'DNS': 122, 'TLSv1': 110, 'HTTP': 2}
# 2025-12-08 23:30:39,021 - root - INFO - Processing file: email1a.pcap
# 2025-12-08 23:30:39,580 - root - INFO - Original packets email/email1a.pcap: {'ARP': 15492, 'LLMNR': 5157, 'NBNS': 3767, 'MDNS': 1515, 'UDP': 945, 'TLSv1.2': 660, 'TCP': 505, 'SNMP': 490, 'DB-LSP-DISC/JSON': 480, 'DHCPv6': 337, 'ICMPv6': 317, 'BROWSER': 225, 'SSDP': 130, 'STP': 121, 'DNS': 60, 'IGMPv2': 59, 'IPX SAP': 40, 'NTP': 31, 'TLSv1': 30, 'LLDP': 21, 'VNC': 14, 'LLC': 6, 'DHCP': 5, 'HTTP': 2, 'SRVLOC': 1}
# 2025-12-08 23:30:39,817 - root - INFO - Filtered packets email/email1a.pcap: {'UDP': 945, 'TLSv1.2': 660, 'TCP': 505, 'BROWSER': 225, 'DNS': 60, 'TLSv1': 30, 'HTTP': 2}
# 2025-12-08 23:30:39,818 - root - INFO - Processing file: vpn_email2a.pcap
# 2025-12-08 23:30:40,063 - root - INFO - Original packets email/vpn_email2a.pcap: {'TLSv1.2': 1258, 'TCP': 1202, 'DNS': 154, 'TLSv1': 62, 'ICMP': 13, 'OCSP': 12, 'NTP': 6}
# 2025-12-08 23:30:40,299 - root - INFO - Filtered packets email/vpn_email2a.pcap: {'TLSv1.2': 1258, 'TCP': 1202, 'DNS': 154, 'TLSv1': 62}
# 2025-12-08 23:30:40,301 - root - INFO - Processing file: email1b.pcap
# 2025-12-08 23:30:40,871 - root - INFO - Original packets email/email1b.pcap: {'ARP': 13163, 'LLMNR': 5144, 'NBNS': 3755, 'TLSv1.2': 3362, 'TCP': 2212, 'MDNS': 1508, 'UDP': 939, 'DB-LSP-DISC/JSON': 480, 'SNMP': 370, 'DHCPv6': 344, 'ICMPv6': 336, 'STP': 302, 'BROWSER': 225, 'SSDP': 170, 'DNS': 84, 'IGMPv2': 59, 'IPX SAP': 40, 'TLSv1': 30, 'NTP': 30, 'LLC': 5, 'DHCP': 5, 'OCSP': 2, 'SRVLOC': 1}
# 2025-12-08 23:30:41,172 - root - INFO - Filtered packets email/email1b.pcap: {'TLSv1.2': 3362, 'TCP': 2212, 'UDP': 939, 'BROWSER': 225, 'DNS': 84, 'TLSv1': 30}
# 2025-12-08 23:30:41,173 - root - INFO - Processing folder: facebook
# 2025-12-08 23:30:41,173 - root - INFO - Processing file: facebookchat1.pcap
# 2025-12-08 23:30:41,389 - root - INFO - Original packets facebook/facebookchat1.pcap: {'TLSv1.2': 563, 'TCP': 380, 'DNS': 116, 'ARP': 2}
# 2025-12-08 23:30:41,584 - root - INFO - Filtered packets facebook/facebookchat1.pcap: {'TLSv1.2': 563, 'TCP': 380, 'DNS': 116}
# 2025-12-08 23:30:41,585 - root - INFO - Processing file: facebook_audio2b.pcap
# 2025-12-08 23:30:43,283 - root - INFO - Original packets facebook/facebook_audio2b.pcap: {'UDP': 83909, 'STUN': 8323, 'ICMP': 643, 'TLSv1.2': 507, 'TCP': 506, 'ARP': 84, 'SSL': 45, 'GQUIC': 22, 'DNS': 14, 'LLMNR': 12, 'DTLSv1.0': 10, 'NBNS': 9, 'TLSv1': 5, 'DTLS': 3}
# 2025-12-08 23:30:44,644 - root - INFO - Filtered packets facebook/facebook_audio2b.pcap: {'SRTP': 82405, 'SRTCP': 1504, 'TLSv1.2': 507, 'TCP': 506, 'SSL': 45, 'GQUIC': 22, 'DNS': 14, 'DTLSv1.0': 10, 'TLSv1': 5, 'DTLS': 3}
# 2025-12-08 23:30:44,645 - root - INFO - Processing file: facebook_audio3.pcap
# 2025-12-08 23:30:54,767 - root - INFO - Original packets facebook/facebook_audio3.pcap: {'UDP': 598393, 'STUN': 37628, 'TCP': 3357, 'TLSv1.2': 1787, 'SSDP': 558, 'ICMP': 304, 'ICMPv6': 194, 'BROWSER': 160, 'DNS': 146, 'DHCPv6': 104, 'NBNS': 84, 'GQUIC': 81, 'LLMNR': 80, 'ARP': 58, 'HTTP': 44, 'TLSv1': 36, 'HTTP/XML': 16, 'IPv6': 9, 'LLDP': 6, 'IGMPv3': 2, 'HTTP/JSON': 2}
# 2025-12-08 23:31:04,811 - root - INFO - Filtered packets facebook/facebook_audio3.pcap: {'UDP': 598393, 'TCP': 3357, 'TLSv1.2': 1778, 'BROWSER': 160, 'DNS': 146, 'GQUIC': 81, 'HTTP': 44, 'TLSv1': 36, 'HTTP/XML': 16, 'IPv6': 9, 'HTTP/JSON': 2}
# 2025-12-08 23:31:04,812 - root - INFO - Processing file: facebook_chat_4b.pcap
# 2025-12-08 23:31:05,104 - root - INFO - Original packets facebook/facebook_chat_4b.pcap: {'SNMP': 1761, 'TLSv1.2': 1391, 'TCP': 1323, 'LLMNR': 545, 'NBNS': 412, 'ARP': 42, 'GQUIC': 26, 'DNS': 20, 'TLSv1': 6, 'BROWSER': 1}
# 2025-12-08 23:31:05,359 - root - INFO - Filtered packets facebook/facebook_chat_4b.pcap: {'TLSv1.2': 1391, 'TCP': 1323, 'GQUIC': 26, 'DNS': 20, 'TLSv1': 6, 'BROWSER': 1}
# 2025-12-08 23:31:05,360 - root - INFO - Processing file: facebookchat2.pcap
# 2025-12-08 23:31:05,562 - root - INFO - Original packets facebook/facebookchat2.pcap: {'TLSv1.2': 190, 'TCP': 165, 'DNS': 50, 'GQUIC': 9, 'LLMNR': 8, 'NBNS': 7, 'UDP': 4, 'TLSv1': 1}
# 2025-12-08 23:31:05,763 - root - INFO - Filtered packets facebook/facebookchat2.pcap: {'TLSv1.2': 190, 'TCP': 165, 'DNS': 50, 'GQUIC': 9, 'UDP': 4, 'TLSv1': 1}
# 2025-12-08 23:31:05,764 - root - INFO - Processing file: facebook_audio1a.pcap
# 2025-12-08 23:31:06,671 - root - INFO - Original packets facebook/facebook_audio1a.pcap: {'UDP': 41928, 'STUN': 2769, 'TCP': 644, 'TLSv1.2': 404, 'DNS': 150, 'SSL': 48, 'ARP': 42, 'ICMP': 34, 'IGMPv3': 12, 'DTLSv1.0': 10, 'SSDP': 9, 'NBNS': 3, 'BROWSER': 3, 'TLSv1': 2, 'DTLS': 2, 'MDNS': 1}
# 2025-12-08 23:31:07,448 - root - INFO - Filtered packets facebook/facebook_audio1a.pcap: {'SRTP': 41173, 'SRTCP': 755, 'TCP': 644, 'TLSv1.2': 404, 'DNS': 150, 'SSL': 48, 'DTLSv1.0': 10, 'BROWSER': 3, 'TLSv1': 2, 'DTLS': 2}
# 2025-12-08 23:31:07,449 - root - INFO - Processing file: facebookchat3.pcap
# 2025-12-08 23:31:07,678 - root - INFO - Original packets facebook/facebookchat3.pcap: {'TLSv1.2': 805, 'TCP': 620, 'DNS': 166, 'UDP': 46, 'SSL': 45, 'TLSv1': 14, 'TLSv1.1': 8, 'LLMNR': 8, 'ARP': 8, 'NBNS': 6}
# 2025-12-08 23:31:07,898 - root - INFO - Filtered packets facebook/facebookchat3.pcap: {'TLSv1.2': 805, 'TCP': 620, 'DNS': 166, 'UDP': 46, 'SSL': 45, 'TLSv1': 14, 'TLSv1.1': 8}
# 2025-12-08 23:31:07,899 - root - INFO - Processing file: facebook_audio1b.pcap
# 2025-12-08 23:31:08,828 - root - INFO - Original packets facebook/facebook_audio1b.pcap: {'UDP': 41928, 'STUN': 4200, 'TCP': 563, 'TLSv1.2': 463, 'ICMP': 325, 'SSL': 56, 'ARP': 48, 'HTTP': 32, 'DNS': 22, 'LLMNR': 12, 'NBNS': 10, 'DTLSv1.0': 10, 'TLSv1': 6, 'DTLS': 2}
# 2025-12-08 23:31:09,679 - root - INFO - Filtered packets facebook/facebook_audio1b.pcap: {'SRTP': 41173, 'SRTCP': 755, 'TCP': 563, 'TLSv1.2': 463, 'SSL': 56, 'HTTP': 32, 'DNS': 22, 'DTLSv1.0': 10, 'TLSv1': 6, 'DTLS': 2}
# 2025-12-08 23:31:09,680 - root - INFO - Processing file: facebook_video2b.pcap
# 2025-12-08 23:31:13,941 - root - INFO - Original packets facebook/facebook_video2b.pcap: {'UDP': 238698, 'STUN': 5652, 'TCP': 529, 'ICMP': 442, 'TLSv1.2': 327, 'ARP': 58, 'SSL': 35, 'DTLSv1.0': 10, 'LLMNR': 8, 'NBNS': 6, 'DNS': 6, 'TLSv1': 4, 'DTLS': 2}
# 2025-12-08 23:31:17,786 - root - INFO - Filtered packets facebook/facebook_video2b.pcap: {'SRTP': 233897, 'SRTCP': 4801, 'TCP': 529, 'TLSv1.2': 327, 'SSL': 35, 'DTLSv1.0': 10, 'DNS': 6, 'TLSv1': 4, 'DTLS': 2}
# 2025-12-08 23:31:17,787 - root - INFO - Processing file: vpn_facebook_chat1a.pcap
# 2025-12-08 23:31:18,102 - root - INFO - Original packets facebook/vpn_facebook_chat1a.pcap: {'TCP': 4206, 'TLSv1.2': 3459, 'DNS': 1052, 'TLSv1': 36, 'UDP': 18, 'ICMP': 18, 'OCSP': 10, 'NTP': 2}
# 2025-12-08 23:31:18,424 - root - INFO - Filtered packets facebook/vpn_facebook_chat1a.pcap: {'TCP': 4206, 'TLSv1.2': 3458, 'DNS': 1052, 'TLSv1': 36, 'UDP': 18}
# 2025-12-08 23:31:18,425 - root - INFO - Processing file: facebook_video1b.pcap
# 2025-12-08 23:31:20,278 - root - INFO - Original packets facebook/facebook_video1b.pcap: {'UDP': 90591, 'STUN': 1678, 'ICMP': 146, 'TLSv1.2': 129, 'TCP': 113, 'ARP': 24, 'TLSv1': 4, 'LLMNR': 4, 'NBNS': 3}
# 2025-12-08 23:31:22,054 - root - INFO - Filtered packets facebook/facebook_video1b.pcap: {'UDP': 90591, 'TLSv1.2': 129, 'TCP': 113, 'TLSv1': 4}
# 2025-12-08 23:31:22,055 - root - INFO - Processing file: facebook_video1a.pcap
# 2025-12-08 23:31:24,877 - root - INFO - Original packets facebook/facebook_video1a.pcap: {'UDP': 152649, 'STUN': 2605, 'TCP': 919, 'TLSv1.2': 488, 'DNS': 152, 'SSL': 57, 'ARP': 42, 'ICMP': 39, 'DTLSv1.0': 10, 'IGMPv3': 8, 'BROWSER': 7, 'SSDP': 6, 'TLSv1': 3, 'NBNS': 2, 'DTLS': 2}
# 2025-12-08 23:31:27,237 - root - INFO - Filtered packets facebook/facebook_video1a.pcap: {'SRTP': 149612, 'SRTCP': 3037, 'TCP': 919, 'TLSv1.2': 488, 'DNS': 152, 'SSL': 57, 'DTLSv1.0': 10, 'BROWSER': 7, 'TLSv1': 3, 'DTLS': 2}
# 2025-12-08 23:31:27,238 - root - INFO - Processing file: facebook_chat_4a.pcap
# 2025-12-08 23:31:27,468 - root - INFO - Original packets facebook/facebook_chat_4a.pcap: {'TLSv1.2': 1287, 'TCP': 760, 'LLMNR': 44, 'NBNS': 36, 'DNS': 26, 'GQUIC': 18, 'UDP': 8, 'ARP': 6, 'TLSv1': 5, 'NTP': 2}
# 2025-12-08 23:31:27,698 - root - INFO - Filtered packets facebook/facebook_chat_4a.pcap: {'TLSv1.2': 1287, 'TCP': 760, 'DNS': 26, 'GQUIC': 18, 'UDP': 8, 'TLSv1': 5}
# 2025-12-08 23:31:27,699 - root - INFO - Processing file: facebook_audio2a.pcap
# 2025-12-08 23:31:29,398 - root - INFO - Original packets facebook/facebook_audio2a.pcap: {'UDP': 83909, 'STUN': 5447, 'TCP': 1203, 'TLSv1.2': 601, 'DNS': 322, 'ARP': 78, 'ICMP': 63, 'SSL': 48, 'IGMPv3': 24, 'GQUIC': 19, 'TLSv1': 18, 'SSDP': 18, 'SMB2': 13, 'SMB': 13, 'DTLSv1.0': 10, 'BROWSER': 9, 'NBNS': 7, 'NBSS': 4, 'LANMAN': 4, 'DTLS': 3, 'OCSP': 2}
# 2025-12-08 23:31:30,875 - root - INFO - Filtered packets facebook/facebook_audio2a.pcap: {'SRTP': 82405, 'SRTCP': 1504, 'TCP': 1203, 'TLSv1.2': 601, 'DNS': 322, 'SSL': 48, 'GQUIC': 19, 'TLSv1': 18, 'SMB2': 13, 'SMB': 13, 'DTLSv1.0': 10, 'BROWSER': 9, 'NBSS': 4, 'DTLS': 3}
# 2025-12-08 23:31:30,876 - root - INFO - Processing file: vpn_facebook_audio2.pcap
# 2025-12-08 23:31:31,314 - root - INFO - Original packets facebook/vpn_facebook_audio2.pcap: {'TCP': 6066, 'TLSv1.2': 5804, 'DNS': 2264, 'STUN': 485, 'SSL': 196, 'ICMP': 186, 'TLSv1': 77, 'OCSP': 12, 'SSLv3': 2, 'HTTP': 2}
# 2025-12-08 23:31:31,742 - root - INFO - Filtered packets facebook/vpn_facebook_audio2.pcap: {'TCP': 6066, 'TLSv1.2': 5804, 'DNS': 2264, 'SSL': 196, 'TLSv1': 77, 'SSLv3': 2, 'HTTP': 2}
# 2025-12-08 23:31:31,744 - root - INFO - Processing file: facebook_video2a.pcap
# 2025-12-08 23:31:36,021 - root - INFO - Original packets facebook/facebook_video2a.pcap: {'UDP': 238698, 'STUN': 3755, 'TCP': 1163, 'TLSv1.2': 546, 'DNS': 204, 'ARP': 62, 'SSL': 49, 'ICMP': 33, 'GQUIC': 31, 'SMB2': 21, 'IGMPv3': 14, 'DTLSv1.0': 10, 'SSDP': 9, 'TLSv1': 8, 'BROWSER': 5, 'NBNS': 4, 'SPOOLSS': 2, 'DTLS': 2, 'DCERPC': 2, 'SMB': 1}
# 2025-12-08 23:31:39,763 - root - INFO - Filtered packets facebook/facebook_video2a.pcap: {'SRTP': 233897, 'SRTCP': 4801, 'TCP': 1163, 'TLSv1.2': 546, 'DNS': 204, 'SSL': 49, 'GQUIC': 31, 'SMB2': 21, 'DTLSv1.0': 10, 'TLSv1': 8, 'BROWSER': 5, 'DTLS': 2, 'SMB': 1}
# 2025-12-08 23:31:39,764 - root - INFO - Processing file: facebook_audio4.pcap
# 2025-12-08 23:31:54,899 - root - INFO - Original packets facebook/facebook_audio4.pcap: {'UDP': 611211, 'LLMNR': 187344, 'ARP': 102376, 'NBNS': 86326, 'STUN': 24712, 'DB-LSP-DISC/JSON': 4828, 'MDNS': 4073, 'DHCPv6': 3763, 'ICMPv6': 3391, 'TCP': 2058, 'TLSv1.2': 1865, 'SSDP': 1586, 'BROWSER': 1230, 'STP': 1177, 'DNS': 806, 'ICMP': 804, 'IGMPv2': 799, 'NTP': 686, 'IPX SAP': 392, 'LLDP': 196, 'SSL': 112, 'DHCP': 95, 'IGMPv3': 61, 'SRVLOC': 57, 'LLC': 45, 'TLSv1': 38, 'OCSP': 4, 'Elasticsearch': 2}
# 2025-12-08 23:32:05,180 - root - INFO - Filtered packets facebook/facebook_audio4.pcap: {'UDP': 611211, 'TCP': 2058, 'TLSv1.2': 1865, 'BROWSER': 1230, 'DNS': 806, 'SSL': 112, 'TLSv1': 38, 'Elasticsearch': 2}
# 2025-12-08 23:32:05,181 - root - INFO - Processing file: vpn_facebook_chat1b.pcap
# 2025-12-08 23:32:05,485 - root - INFO - Original packets facebook/vpn_facebook_chat1b.pcap: {'TCP': 3325, 'TLSv1.2': 3074, 'DNS': 1136, 'ICMP': 29, 'TLSv1': 3}
# 2025-12-08 23:32:05,791 - root - INFO - Filtered packets facebook/vpn_facebook_chat1b.pcap: {'TCP': 3325, 'TLSv1.2': 3074, 'DNS': 1136, 'TLSv1': 3}
# 2025-12-08 23:32:05,792 - root - INFO - Processing folder: gmail
# 2025-12-08 23:32:05,793 - root - INFO - Processing file: gmailchat3.pcap
# 2025-12-08 23:32:06,114 - root - INFO - Original packets gmail/gmailchat3.pcap: {'UDP': 3104, 'TCP': 1732, 'TLSv1.2': 1383, 'DNS': 614, 'GQUIC': 157, 'SSL': 114, 'LLMNR': 60, 'TLSv1': 58, 'NBNS': 45, 'TLSv1.1': 31, 'ARP': 28, 'NTP': 2, 'ICMP': 1}
# 2025-12-08 23:32:06,437 - root - INFO - Filtered packets gmail/gmailchat3.pcap: {'UDP': 3104, 'TCP': 1732, 'TLSv1.2': 1383, 'DNS': 614, 'GQUIC': 157, 'SSL': 114, 'TLSv1': 58, 'TLSv1.1': 31}
# 2025-12-08 23:32:06,438 - root - INFO - Processing file: gmailchat2.pcap
# 2025-12-08 23:32:06,684 - root - INFO - Original packets gmail/gmailchat2.pcap: {'TCP': 1051, 'GQUIC': 938, 'TLSv1.2': 682, 'DNS': 268, 'UDP': 150, 'LLMNR': 20, 'NBNS': 15, 'TLSv1': 13, 'NTP': 2, 'HTTP': 2, 'ARP': 2}
# 2025-12-08 23:32:06,940 - root - INFO - Filtered packets gmail/gmailchat2.pcap: {'TCP': 1051, 'GQUIC': 938, 'TLSv1.2': 682, 'DNS': 268, 'UDP': 150, 'TLSv1': 13, 'HTTP': 2}
# 2025-12-08 23:32:06,941 - root - INFO - Processing file: gmailchat1.pcap
# 2025-12-08 23:32:07,186 - root - INFO - Original packets gmail/gmailchat1.pcap: {'GQUIC': 567, 'TCP': 466, 'TLSv1.2': 437, 'DNS': 190, 'UDP': 123, 'TLSv1': 6, 'LLMNR': 4, 'NBNS': 3, 'NTP': 2, 'ARP': 2}
# 2025-12-08 23:32:07,410 - root - INFO - Filtered packets gmail/gmailchat1.pcap: {'GQUIC': 567, 'TCP': 466, 'TLSv1.2': 437, 'DNS': 190, 'UDP': 123, 'TLSv1': 6}
