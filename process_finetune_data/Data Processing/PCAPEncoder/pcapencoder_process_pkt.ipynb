# %% [markdown]
# # Description
# process et-bert data for fine-tuning
# label.pcap (tsv format) -> train/validation/test.tsv

# %%
import os
import logging
import scapy.all as scapy
import random
import binascii
import csv
import json
import numpy as np
import pandas as pd
from multiprocessing import Pool, cpu_count

# %%
dataset = '/root/Traffic/flow-level-classification/vpn-app'

dataset_path = f'{dataset}'
output_path = f'/root/Traffic/code/PCAP_encoder/1.Datasets/Classification/vpn-app'
output_withoutIP_path = f'/root/Traffic/code/PCAP_encoder/1.Datasets/Classification/without_IP/vpn-app'

os.makedirs(output_path, exist_ok=True)
os.makedirs(output_withoutIP_path, exist_ok=True)

# %%
def clean_packet(packet):
    if packet.haslayer(scapy.Ether):
        packet = packet[scapy.Ether].payload

    if packet.haslayer(scapy.IP):
        packet[scapy.IP].src = "0.0.0.0"
        packet[scapy.IP].dst = "0.0.0.0"
    elif packet.haslayer('IPv6'):
        packet['IPv6'].src = "::"
        packet['IPv6'].dst = "::"

    if packet.haslayer(scapy.UDP):
        packet[scapy.UDP].sport = 0 
        packet[scapy.UDP].dport = 0  
    elif packet.haslayer(scapy.TCP):
        packet[scapy.TCP].sport = 0  
        packet[scapy.TCP].dport = 0  
    
    return packet

# %%
def group_string_by_n(pkt, n=4):
    s = binascii.hexlify(bytes(pkt)).decode()
    return ' '.join(s[i:i+n] for i in range(0, len(s), n))
class_indexs = {
    'aim': 0, 'facebook': 1, 'gmail': 2, 'icq': 3,
    'scp': 4, 'skype': 5, 'torrent': 6, 'voipbuster': 7,
    'email': 8, 'ftp': 9, 'hangout': 10, 'netflix': 11,
    'sftp': 12, 'spotify': 13, 'vimeo': 14, 'youtube': 15
}
for split_folder in os.listdir(dataset_path):
    print(f"Processing file: {split_folder}")
    if split_folder not in ['train_val_split_0']:
        continue
    if split_folder == 'test':
        dataset_file = [['question', 'class', 'type_q', 'context']]
        for label in os.listdir(f"{dataset_path}/{split_folder}"):
            for file in os.listdir(f"{dataset_path}/{split_folder}/{label}"):
                if file.endswith('.pcap'):
                    print(f"Processing file: {file}")
                    with scapy.PcapReader(f"{dataset_path}/{split_folder}/{label}/{file}") as pkt_reader:
                        for pkt in pkt_reader:
                            pkt = clean_packet(pkt)
                            context = group_string_by_n(pkt)
                            dataset_file.append(['What is the representation of this packet?', class_indexs[label], label, context])
        os.makedirs(f"{output_withoutIP_path}", exist_ok=True)
        output_dataframe = pd.DataFrame(dataset_file[1:], columns=dataset_file[0])
        output_dataframe.to_parquet(f"{output_withoutIP_path}/{split_folder}.parquet", index=False)
        print(f"Saved {output_withoutIP_path}/{split_folder}.parquet")
    else:
        for type in os.listdir(f"{dataset_path}/{split_folder}"):
            if type not in ['train']:
                continue
            dataset_file = [['question', 'class', 'type_q', 'context']]
            for label in os.listdir(f"{dataset_path}/{split_folder}/{type}"):    
                for file in os.listdir(f"{dataset_path}/{split_folder}/{type}/{label}"):
                    if file.endswith('.pcap'):
                        print(f"Processing file: {file}")
                        with scapy.PcapReader(f"{dataset_path}/{split_folder}/{type}/{label}/{file}") as pkt_reader:
                            for pkt in pkt_reader:
                                pkt = clean_packet(pkt)
                                context = group_string_by_n(pkt)
                                dataset_file.append(['What is the representation of this packet?', class_indexs[label], label, context])
            
            os.makedirs(f"{output_withoutIP_path}/{split_folder}", exist_ok=True)
            output_dataframe = pd.DataFrame(dataset_file[1:], columns=dataset_file[0])
            output_dataframe.to_parquet(f"{output_withoutIP_path}/{split_folder}/{type}.parquet", index=False)
            print(f"Saved {output_withoutIP_path}/{split_folder}/{type}.parquet")
# Out:
# Processing file: __MACOSX
# Processing file: MRF
# Processing file: train_val_split_0
# Processing file: 249.pcap
# Processing file: 00002.pcap
# Processing file: 26.pcap
# Processing file: 00017.pcap
# Processing file: 311.pcap
# Processing file: 310.pcap
# Processing file: 00014.pcap
# Processing file: 00005.pcap
# Processing file: 210.pcap
# Processing file: 303.pcap
# Processing file: 00025.pcap
# Processing file: 00032.pcap
# Processing file: 286.pcap
# Processing file: 00031.pcap
# Processing file: 216.pcap
# Processing file: 00030.pcap
# Processing file: 313.pcap
# Processing file: 00026.pcap
# Processing file: 299.pcap
# Processing file: 00006.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 00010.pcap
# Processing file: 284.pcap
# Processing file: 100.pcap
# Processing file: 253.pcap
# Processing file: 00001.pcap
# Processing file: 00020.pcap
# Processing file: 197.pcap
# Processing file: 00023.pcap
# Processing file: 00008.pcap
# Processing file: 212.pcap
# Processing file: 190.pcap
# Processing file: 00024.pcap
# Processing file: 283.pcap
# Processing file: 62.pcap
# Processing file: 00019.pcap
# Processing file: 00021.pcap
# Processing file: 64.pcap
# Processing file: 38.pcap
# Processing file: 00003.pcap
# Processing file: 13.pcap
# Processing file: 00009.pcap
# Processing file: 60.pcap
# Processing file: 00027.pcap
# Processing file: 329.pcap
# Processing file: 145.pcap
# Processing file: 00002.pcap
# Processing file: 00028.pcap
# Processing file: 314.pcap
# Processing file: 00014.pcap
# Processing file: 321.pcap
# Processing file: 00005.pcap
# Processing file: 106.pcap
# Processing file: 00025.pcap
# Processing file: 00032.pcap
# Processing file: 00031.pcap
# Processing file: 49.pcap
# Processing file: 256.pcap
# Processing file: 00030.pcap
# Processing file: 00026.pcap
# Processing file: 272.pcap
# Processing file: 268.pcap
# Processing file: 00011.pcap
# Processing file: 00006.pcap
# Processing file: 94.pcap
# Processing file: 00007.pcap
# Processing file: 00010.pcap
# Processing file: 162.pcap
# Processing file: 277.pcap
# Processing file: 136.pcap
# Processing file: 00029.pcap
# Processing file: 00001.pcap
# Processing file: 55.pcap
# Processing file: 291.pcap
# Processing file: 00020.pcap
# Processing file: 315.pcap
# Processing file: 00008.pcap
# Processing file: 205.pcap
# Processing file: 00022.pcap
# Processing file: 193.pcap
# Processing file: 236.pcap
# Processing file: 00021.pcap
# Processing file: 255.pcap
# Processing file: 292.pcap
# Processing file: 00000.pcap
# Processing file: 00003.pcap
# Processing file: 207.pcap
# Processing file: 201.pcap
# Processing file: 00027.pcap
# Processing file: 159.pcap
# Processing file: 00017.pcap
# Processing file: 00028.pcap
# Processing file: 246.pcap
# Processing file: 00005.pcap
# Processing file: 70.pcap
# Processing file: 44.pcap
# Processing file: 00032.pcap
# Processing file: 63.pcap
# Processing file: 172.pcap
# Processing file: 289.pcap
# Processing file: 00030.pcap
# Processing file: 333.pcap
# Processing file: 00011.pcap
# Processing file: 30.pcap
# Processing file: 288.pcap
# Processing file: 00004.pcap
# Processing file: 00015.pcap
# Processing file: 351.pcap
# Processing file: 229.pcap
# Processing file: 00010.pcap
# Processing file: 61.pcap
# Processing file: 319.pcap
# Processing file: 00013.pcap
# Processing file: 309.pcap
# Processing file: 00029.pcap
# Processing file: 00001.pcap
# Processing file: 00020.pcap
# Processing file: 87.pcap
# Processing file: 114.pcap
# Processing file: 00023.pcap
# Processing file: 124.pcap
# Processing file: 00008.pcap
# Processing file: 23.pcap
# Processing file: 00022.pcap
# Processing file: 00024.pcap
# Processing file: 208.pcap
# Processing file: 00019.pcap
# Processing file: 00021.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 153.pcap
# Processing file: 194.pcap
# Processing file: 307.pcap
# Processing file: 264.pcap
# Processing file: 00002.pcap
# Processing file: 280.pcap
# Processing file: 00017.pcap
# Processing file: 00028.pcap
# Processing file: 00014.pcap
# Processing file: 00005.pcap
# Processing file: 215.pcap
# Processing file: 42.pcap
# Processing file: 00025.pcap
# Processing file: 118.pcap
# Processing file: 00031.pcap
# Processing file: 00030.pcap
# Processing file: 00026.pcap
# Processing file: 270.pcap
# Processing file: 00012.pcap
# Processing file: 00011.pcap
# Processing file: 32.pcap
# Processing file: 00006.pcap
# Processing file: 295.pcap
# Processing file: 147.pcap
# Processing file: 00004.pcap
# Processing file: 00007.pcap
# Processing file: 296.pcap
# Processing file: 19.pcap
# Processing file: 302.pcap
# Processing file: 00016.pcap
# Processing file: 00029.pcap
# Processing file: 185.pcap
# Processing file: 00023.pcap
# Processing file: 00008.pcap
# Processing file: 161.pcap
# Processing file: 00024.pcap
# Processing file: 00019.pcap
# Processing file: 113.pcap
# Processing file: 43.pcap
# Processing file: 00021.pcap
# Processing file: 17.pcap
# Processing file: 233.pcap
# Processing file: 95.pcap
# Processing file: 00009.pcap
# Processing file: 165.pcap
# Processing file: 146.pcap
# Processing file: 00027.pcap
# Processing file: 228.pcap
# Processing file: 120.pcap
# Processing file: 00002.pcap
# Processing file: 00017.pcap
# Processing file: 102.pcap
# Processing file: 00028.pcap
# Processing file: 152.pcap
# Processing file: 00014.pcap
# Processing file: 00005.pcap
# Processing file: 260.pcap
# Processing file: 00032.pcap
# Processing file: 00031.pcap
# Processing file: 121.pcap
# Processing file: 334.pcap
# Processing file: 41.pcap
# Processing file: 00026.pcap
# Processing file: 139.pcap
# Processing file: 00011.pcap
# Processing file: 00006.pcap
# Processing file: 221.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 230.pcap
# Processing file: 00010.pcap
# Processing file: 261.pcap
# Processing file: 245.pcap
# Processing file: 8.pcap
# Processing file: 00013.pcap
# Processing file: 176.pcap
# Processing file: 217.pcap
# Processing file: 129.pcap
# Processing file: 00016.pcap
# Processing file: 00001.pcap
# Processing file: 00020.pcap
# Processing file: 213.pcap
# Processing file: 00023.pcap
# Processing file: 199.pcap
# Processing file: 00008.pcap
# Processing file: 51.pcap
# Processing file: 110.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 259.pcap
# Processing file: 00027.pcap
# Processing file: 18.pcap
# Processing file: 58.pcap
# Processing file: 59.pcap
# Processing file: 00002.pcap
# Processing file: 00017.pcap
# Processing file: 00028.pcap
# Processing file: 00014.pcap
# Processing file: 00005.pcap
# Processing file: 2.pcap
# Processing file: 00025.pcap
# Processing file: 00032.pcap
# Processing file: 5.pcap
# Processing file: 00031.pcap
# Processing file: 91.pcap
# Processing file: 00030.pcap
# Processing file: 214.pcap
# Processing file: 00011.pcap
# Processing file: 00006.pcap
# Processing file: 00004.pcap
# Processing file: 00007.pcap
# Processing file: 00010.pcap
# Processing file: 35.pcap
# Processing file: 28.pcap
# Processing file: 00013.pcap
# Processing file: 155.pcap
# Processing file: 328.pcap
# Processing file: 00016.pcap
# Processing file: 00029.pcap
# Processing file: 00001.pcap
# Processing file: 21.pcap
# Processing file: 340.pcap
# Processing file: 131.pcap
# Processing file: 141.pcap
# Processing file: 177.pcap
# Processing file: 200.pcap
# Processing file: 108.pcap
# Processing file: 00022.pcap
# Processing file: 00019.pcap
# Processing file: 160.pcap
# Processing file: 90.pcap
# Processing file: 266.pcap
# Processing file: 00009.pcap
# Processing file: 99.pcap
# Processing file: 234.pcap
# Processing file: 00002.pcap
# Processing file: 184.pcap
# Processing file: 00014.pcap
# Processing file: 305.pcap
# Processing file: 6.pcap
# Processing file: 158.pcap
# Processing file: 112.pcap
# Processing file: 00025.pcap
# Processing file: 34.pcap
# Processing file: 48.pcap
# Processing file: 179.pcap
# Processing file: 301.pcap
# Processing file: 00031.pcap
# Processing file: 00030.pcap
# Processing file: 00026.pcap
# Processing file: 11.pcap
# Processing file: 166.pcap
# Processing file: 00018.pcap
# Processing file: 00011.pcap
# Processing file: 00006.pcap
# Processing file: 47.pcap
# Processing file: 00004.pcap
# Processing file: 00007.pcap
# Processing file: 150.pcap
# Processing file: 00013.pcap
# Processing file: 00016.pcap
# Processing file: 00029.pcap
# Processing file: 278.pcap
# Processing file: 343.pcap
# Processing file: 00023.pcap
# Processing file: 00008.pcap
# Processing file: 101.pcap
# Processing file: 226.pcap
# Processing file: 00022.pcap
# Processing file: 00024.pcap
# Processing file: 276.pcap
# Processing file: 00019.pcap
# Processing file: 262.pcap
# Processing file: 00000.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 251.pcap
# Processing file: 39.pcap
# Processing file: 298.pcap
# Processing file: 231.pcap
# Processing file: 00027.pcap
# Processing file: 274.pcap
# Processing file: 00002.pcap
# Processing file: 00017.pcap
# Processing file: 225.pcap
# Processing file: 222.pcap
# Processing file: 00014.pcap
# Processing file: 00005.pcap
# Processing file: 69.pcap
# Processing file: 154.pcap
# Processing file: 00025.pcap
# Processing file: 331.pcap
# Processing file: 00032.pcap
# Processing file: 00030.pcap
# Processing file: 00012.pcap
# Processing file: 00018.pcap
# Processing file: 254.pcap
# Processing file: 00011.pcap
# Processing file: 00010.pcap
# Processing file: 237.pcap
# Processing file: 325.pcap
# Processing file: 238.pcap
# Processing file: 00016.pcap
# Processing file: 00029.pcap
# Processing file: 00001.pcap
# Processing file: 1.pcap
# Processing file: 00008.pcap
# Processing file: 341.pcap
# Processing file: 78.pcap
# Processing file: 12.pcap
# Processing file: 00022.pcap
# Processing file: 00024.pcap
# Processing file: 122.pcap
# Processing file: 31.pcap
# Processing file: 00019.pcap
# Processing file: 151.pcap
# Processing file: 241.pcap
# Processing file: 00021.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 203.pcap
# Processing file: 312.pcap
# Processing file: 188.pcap
# Processing file: 105.pcap
# Processing file: 00027.pcap
# Processing file: 140.pcap
# Processing file: 00002.pcap
# Processing file: 00017.pcap
# Processing file: 00014.pcap
# Processing file: 130.pcap
# Processing file: 00025.pcap
# Processing file: 00032.pcap
# Processing file: 00031.pcap
# Processing file: 220.pcap
# Processing file: 174.pcap
# Processing file: 00030.pcap
# Processing file: 337.pcap
# Processing file: 156.pcap
# Processing file: 65.pcap
# Processing file: 00012.pcap
# Processing file: 00011.pcap
# Processing file: 00006.pcap
# Processing file: 00004.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 109.pcap
# Processing file: 290.pcap
# Processing file: 54.pcap
# Processing file: 00013.pcap
# Processing file: 342.pcap
# Processing file: 00016.pcap
# Processing file: 00029.pcap
# Processing file: 16.pcap
# Processing file: 00008.pcap
# Processing file: 71.pcap
# Processing file: 00024.pcap
# Processing file: 3.pcap
# Processing file: 00019.pcap
# Processing file: 196.pcap
# Processing file: 304.pcap
# Processing file: 350.pcap
# Processing file: 344.pcap
# Processing file: 242.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 281.pcap
# Processing file: 00027.pcap
# Processing file: 324.pcap
# Processing file: 171.pcap
# Processing file: 00002.pcap
# Processing file: 300.pcap
# Processing file: 00017.pcap
# Processing file: 00014.pcap
# Processing file: 74.pcap
# Processing file: 293.pcap
# Processing file: 248.pcap
# Processing file: 00025.pcap
# Processing file: 00030.pcap
# Processing file: 00026.pcap
# Processing file: 37.pcap
# Processing file: 00012.pcap
# Processing file: 00006.pcap
# Processing file: 00004.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 00010.pcap
# Processing file: 252.pcap
# Processing file: 00013.pcap
# Processing file: 265.pcap
# Processing file: 125.pcap
# Processing file: 00016.pcap
# Processing file: 219.pcap
# Processing file: 00029.pcap
# Processing file: 00001.pcap
# Processing file: 348.pcap
# Processing file: 00023.pcap
# Processing file: 81.pcap
# Processing file: 00008.pcap
# Processing file: 149.pcap
# Processing file: 308.pcap
# Processing file: 181.pcap
# Processing file: 00024.pcap
# Processing file: 88.pcap
# Processing file: 0.pcap
# Processing file: 29.pcap
# Processing file: 00000.pcap
# Processing file: 00003.pcap
# Processing file: 227.pcap
# Processing file: 273.pcap
# Processing file: 332.pcap
# Processing file: 98.pcap
# Processing file: 00002.pcap
# Processing file: 00017.pcap
# Processing file: 00005.pcap
# Processing file: 338.pcap
# Processing file: 218.pcap
# Processing file: 00032.pcap
# Processing file: 00031.pcap
# Processing file: 142.pcap
# Processing file: 00026.pcap
# Processing file: 00012.pcap
# Processing file: 00006.pcap
# Processing file: 103.pcap
# Processing file: 82.pcap
# Processing file: 133.pcap
# Processing file: 178.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 00010.pcap
# Processing file: 27.pcap
# Processing file: 167.pcap
# Processing file: 169.pcap
# Processing file: 202.pcap
# Processing file: 00029.pcap
# Processing file: 00001.pcap
# Processing file: 00020.pcap
# Processing file: 173.pcap
# Processing file: 75.pcap
# Processing file: 00023.pcap
# Processing file: 00008.pcap
# Processing file: 323.pcap
# Processing file: 339.pcap
# Processing file: 00022.pcap
# Processing file: 00024.pcap
# Processing file: 170.pcap
# Processing file: 137.pcap
# Processing file: 00019.pcap
# Processing file: 33.pcap
# Processing file: 00021.pcap
# Processing file: 349.pcap
# Processing file: 138.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 00027.pcap
# Processing file: 282.pcap
# Processing file: 00002.pcap
# Processing file: 00017.pcap
# Processing file: 00028.pcap
# Processing file: 263.pcap
# Processing file: 243.pcap
# Processing file: 297.pcap
# Processing file: 00025.pcap
# Processing file: 00031.pcap
# Processing file: 46.pcap
# Processing file: 00030.pcap
# Processing file: 104.pcap
# Processing file: 83.pcap
# Processing file: 20.pcap
# Processing file: 00018.pcap
# Processing file: 00011.pcap
# Processing file: 96.pcap
# Processing file: 00006.pcap
# Processing file: 84.pcap
# Processing file: 4.pcap
# Processing file: 330.pcap
# Processing file: 00004.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 247.pcap
# Processing file: 00013.pcap
# Processing file: 115.pcap
# Processing file: 00016.pcap
# Processing file: 00001.pcap
# Processing file: 00020.pcap
# Processing file: 72.pcap
# Processing file: 15.pcap
# Processing file: 224.pcap
# Processing file: 00022.pcap
# Processing file: 117.pcap
# Processing file: 45.pcap
# Processing file: 00021.pcap
# Processing file: 186.pcap
# Processing file: 00000.pcap
# Processing file: 00003.pcap
# Processing file: 79.pcap
# Processing file: 00009.pcap
# Processing file: 244.pcap
# Processing file: 9.pcap
# Processing file: 235.pcap
# Processing file: 00027.pcap
# Processing file: 306.pcap
# Processing file: 00017.pcap
# Processing file: 00028.pcap
# Processing file: 258.pcap
# Processing file: 326.pcap
# Processing file: 00025.pcap
# Processing file: 00032.pcap
# Processing file: 24.pcap
# Processing file: 00031.pcap
# Processing file: 187.pcap
# Processing file: 00030.pcap
# Processing file: 123.pcap
# Processing file: 00012.pcap
# Processing file: 00018.pcap
# Processing file: 00011.pcap
# Processing file: 77.pcap
# Processing file: 85.pcap
# Processing file: 287.pcap
# Processing file: 00004.pcap
# Processing file: 00015.pcap
# Processing file: 86.pcap
# Processing file: 00007.pcap
# Processing file: 68.pcap
# Processing file: 00010.pcap
# Processing file: 275.pcap
# Processing file: 157.pcap
# Processing file: 223.pcap
# Processing file: 182.pcap
# Processing file: 67.pcap
# Processing file: 00029.pcap
# Processing file: 144.pcap
# Processing file: 00023.pcap
# Processing file: 00008.pcap
# Processing file: 00022.pcap
# Processing file: 00024.pcap
# Processing file: 00019.pcap
# Processing file: 00021.pcap
# Processing file: 183.pcap
# Processing file: 119.pcap
# Processing file: 204.pcap
# Processing file: 00009.pcap
# Processing file: 335.pcap
# Processing file: 240.pcap
# Processing file: 336.pcap
# Processing file: 00002.pcap
# Processing file: 00028.pcap
# Processing file: 163.pcap
# Processing file: 00014.pcap
# Processing file: 195.pcap
# Processing file: 346.pcap
# Processing file: 294.pcap
# Processing file: 93.pcap
# Processing file: 00025.pcap
# Processing file: 00032.pcap
# Processing file: 00031.pcap
# Processing file: 00030.pcap
# Processing file: 168.pcap
# Processing file: 00026.pcap
# Processing file: 00012.pcap
# Processing file: 00011.pcap
# Processing file: 111.pcap
# Processing file: 239.pcap
# Processing file: 00004.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 00010.pcap
# Processing file: 00016.pcap
# Processing file: 198.pcap
# Processing file: 327.pcap
# Processing file: 00020.pcap
# Processing file: 92.pcap
# Processing file: 00023.pcap
# Processing file: 148.pcap
# Processing file: 00022.pcap
# Processing file: 00024.pcap
# Processing file: 107.pcap
# Processing file: 00019.pcap
# Processing file: 347.pcap
# Processing file: 66.pcap
# Processing file: 269.pcap
# Processing file: 116.pcap
# Processing file: 317.pcap
# Processing file: 57.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 00027.pcap
# Processing file: 00028.pcap
# Processing file: 00014.pcap
# Processing file: 00005.pcap
# Processing file: 56.pcap
# Processing file: 211.pcap
# Processing file: 00025.pcap
# Processing file: 00032.pcap
# Processing file: 250.pcap
# Processing file: 00031.pcap
# Processing file: 00030.pcap
# Processing file: 126.pcap
# Processing file: 192.pcap
# Processing file: 36.pcap
# Processing file: 180.pcap
# Processing file: 00012.pcap
# Processing file: 00011.pcap
# Processing file: 00006.pcap
# Processing file: 22.pcap
# Processing file: 257.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 00010.pcap
# Processing file: 143.pcap
# Processing file: 175.pcap
# Processing file: 00013.pcap
# Processing file: 53.pcap
# Processing file: 318.pcap
# Processing file: 00020.pcap
# Processing file: 00023.pcap
# Processing file: 00008.pcap
# Processing file: 345.pcap
# Processing file: 00024.pcap
# Processing file: 80.pcap
# Processing file: 279.pcap
# Processing file: 132.pcap
# Processing file: 00021.pcap
# Processing file: 25.pcap
# Processing file: 206.pcap
# Processing file: 285.pcap
# Processing file: 52.pcap
# Processing file: 322.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 10.pcap
# Processing file: 271.pcap
# Processing file: 00027.pcap
# Processing file: 320.pcap
# Processing file: 232.pcap
# Processing file: 00002.pcap
# Processing file: 00028.pcap
# Processing file: 00014.pcap
# Processing file: 00005.pcap
# Processing file: 189.pcap
# Processing file: 00031.pcap
# Processing file: 134.pcap
# Processing file: 76.pcap
# Processing file: 209.pcap
# Processing file: 00030.pcap
# Processing file: 135.pcap
# Processing file: 128.pcap
# Processing file: 00026.pcap
# Processing file: 00011.pcap
# Processing file: 00006.pcap
# Processing file: 73.pcap
# Processing file: 00004.pcap
# Processing file: 50.pcap
# Processing file: 00015.pcap
# Processing file: 00007.pcap
# Processing file: 00010.pcap
# Processing file: 316.pcap
# Processing file: 97.pcap
# Processing file: 127.pcap
# Processing file: 00016.pcap
# Processing file: 00001.pcap
# Processing file: 00020.pcap
# Processing file: 7.pcap
# Processing file: 00023.pcap
# Processing file: 164.pcap
# Processing file: 00008.pcap
# Processing file: 89.pcap
# Processing file: 14.pcap
# Processing file: 00022.pcap
# Processing file: 267.pcap
# Processing file: 40.pcap
# Processing file: 00003.pcap
# Processing file: 00009.pcap
# Processing file: 191.pcap
# Saved /root/Traffic/code/PCAP_encoder/1.Datasets/Classification/without_IP/vpn-app/train_val_split_0/train.parquet
# Processing file: train.zip
