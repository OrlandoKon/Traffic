# %% [markdown]
# # Description
# process et-bert data for fine-tuning
# label.pcap -> train/validation/test.tsv

# %%
import os
import logging
import scapy.all as scapy
import random
import binascii
import csv
import numpy as np
import pandas as pd
from multiprocessing import Pool, cpu_count

os.chdir('/root/data')

logging.basicConfig(       
    level=logging.INFO,            
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',  
    handlers=[
        logging.FileHandler('logs/et-bert_process_flow.log', mode='w'),  
        logging.StreamHandler()          
    ],
    force=True
)

logger = logging.getLogger()

# %%
def cut(obj, sec):
    result = [obj[i:i+sec] for i in range(0,len(obj),sec)]
    try:
        remanent_count = len(result[0])%4
    except Exception as e:
        remanent_count = 0
        print("cut datagram error!")
    if remanent_count == 0:
        pass
    else:
        result = [obj[i:i+sec+remanent_count] for i in range(0,len(obj),sec+remanent_count)]
    return result

def bigram_generation(packet_datagram, packet_len = 64, flag=True):
    result = ''
    generated_datagram = cut(packet_datagram,1)
    token_count = 0
    for sub_string_index in range(len(generated_datagram)):
        if sub_string_index != (len(generated_datagram) - 1):
            token_count += 1
            if token_count > packet_len:
                break
            else:
                merge_word_bigram = generated_datagram[sub_string_index] + generated_datagram[sub_string_index + 1]
        else:
            break
        result += merge_word_bigram
        result += ' '
    
    return result

# %%
dataset = 'ISCX-VPN-2016'
dataset_path = 'ISCX-VPN-2016/filtered/flow'
output_path = f'/root/Traffic/code/ET-BERT/datasets/{dataset}'
os.makedirs(output_path, exist_ok=True)

# %%
# just for packet-level
# type: train, test, val
# file: pcap file
# this is for generating dataset for ET-BERT with pcap and parquet files
# dataset_path/{train_val/test}/class_name/flow.pcap
# dataset_path/{train_val}/{train/val}/class_name/flow.pcap

def clean_packet(packet):
    if packet.haslayer(scapy.Ether):
        packet = packet[scapy.Ether].payload

    if packet.haslayer(scapy.IP):
        packet = packet[scapy.IP].payload
    elif packet.haslayer('IPv6'):
        packet = packet['IPv6'].payload

    if packet.haslayer(scapy.UDP):
        packet[scapy.UDP].sport = 0  
        packet[scapy.UDP].dport = 0  
    elif packet.haslayer(scapy.TCP):
        packet[scapy.TCP].sport = 0  
        packet[scapy.TCP].dport = 0  
    
    return packet

def get_feature_packet(packet, payload_length):
    packet_data_string = ''
    packet_data = packet.copy()
    packet_string = (binascii.hexlify(bytes(packet_data))).decode()[8:]  # remove eth header, ip header and port
    packet_data_string += bigram_generation(packet_string, packet_len=payload_length, flag=True)
    return packet_data_string

def save_to_tsv(dataset_file, output_path, type):
    with open(f"{output_path}/{type}.tsv", 'w', newline='') as f:
        tsv_w = csv.writer(f, delimiter='\t')
        tsv_w.writerows(dataset_file)

def process_file(path, class_name, payload_length):
    dataset_file = [["label", "text_a"]]
    dataset_numpy = []
    dataset_label = []

    pkts = scapy.PcapReader(f"{dataset_path}/{path}.pcap")

    feature_packet = ''
    for id, pkt in enumerate(pkts):
        if id < 5:
            pkt = clean_packet(pkt)
            feature_packet += get_feature_packet(pkt, payload_length)
        else:
            break
    dataset_file.append([int(class_name), feature_packet])
    dataset_numpy.append(feature_packet)
    dataset_label.append(class_name)
    # logger.info(f"Finish processing, the length of dataset is {len(dataset_numpy)}")
    return dataset_file, dataset_numpy, dataset_label

def generate_dataset(dataset_path, output_path, payload_length):
    for type in os.listdir(f'{dataset_path}'):
        logger.info(f"Start processing {dataset_path}/{type}")

        if type == 'test':
            dataset_file_list, dataset_numpy_list, dataset_label_list = [], [], []
            class_id = 0
            for class_name in os.listdir(f'{dataset_path}/{type}'):
                for flow_id, file_name in enumerate(os.listdir(f'{dataset_path}/{type}/{class_name}')):
                    logger.info(f"Start processing {type}/{class_name}/{file_name}")

                    dataset_file, dataset_numpy, dataset_label = process_file(f"{type}/{class_name}/{file_name[:-5]}", class_id, payload_length)

                    if class_id == 0 and flow_id == 0:
                        dataset_file_list.extend(dataset_file)
                    else:
                        dataset_file_list.extend(dataset_file[1:])

                    dataset_numpy_list.extend(dataset_numpy)
                    dataset_label_list.extend(dataset_label)

                class_id += 1
            print(class_id)

            save_to_tsv(dataset_file_list, output_path, type)
            np.save(f"{output_path}/x_payload_{type}.npy", dataset_numpy_list)
            np.save(f"{output_path}/y_label_{type}.npy", dataset_label_list)
        else:
            for folder in os.listdir(f'{dataset_path}/{type}'):
                logger.info(f"Start processing {dataset_path}/{type}/{folder}")
                
                dataset_file_list, dataset_numpy_list, dataset_label_list = [], [], []
                class_id = 0
                for class_name in os.listdir(f'{dataset_path}/{type}/{folder}'):
                    for flow_id, file_name in enumerate(os.listdir(f'{dataset_path}/{type}/{folder}/{class_name}')):
                        logger.info(f"Start processing {dataset_path}/{type}/{folder}/{class_name}/{file_name}")

                        dataset_file, dataset_numpy, dataset_label = process_file(f"{type}/{folder}/{class_name}/{file_name[:-5]}", class_id, payload_length)

                        if class_id == 0 and flow_id == 0:
                            dataset_file_list.extend(dataset_file)
                        else:
                            dataset_file_list.extend(dataset_file[1:])

                        dataset_numpy_list.extend(dataset_numpy)
                        dataset_label_list.extend(dataset_label)

                    class_id += 1
                
                print(class_id)
                save_to_tsv(dataset_file_list, f"{output_path}/{type}", folder)
                np.save(f"{output_path}/{type}/x_payload_{folder}.npy", dataset_numpy_list)
                np.save(f"{output_path}/{type}/y_label_{folder}.npy", dataset_label_list)

# %%
# dataset/type(train, test, validation)/.pcap
generate_dataset(dataset_path, output_path, payload_length = 128)

logger.info(f'Finish')
# main(dataset_path='your_dataset_path', type='your_type', output_path='your_output_path', payload_length=100)
# Out:
# 2025-12-15 15:01:19,237 - root - INFO - Start processing ISCX-VPN-2016/filtered/flow/test
# 2025-12-15 15:01:19,238 - root - INFO - Start processing test/netflix/session_46.pcap
# 2025-12-15 15:01:19,242 - root - INFO - Start processing test/netflix/session_38.pcap
# 2025-12-15 15:01:19,245 - root - INFO - Start processing test/netflix/session_222.pcap
# 2025-12-15 15:01:19,249 - root - INFO - Start processing test/netflix/session_228.pcap
# 2025-12-15 15:01:19,252 - root - INFO - Start processing test/netflix/session_39.pcap
# 2025-12-15 15:01:19,256 - root - INFO - Start processing test/netflix/session_19.pcap
# 2025-12-15 15:01:19,260 - root - INFO - Start processing test/spotify/session_75.pcap
# 2025-12-15 15:01:19,264 - root - INFO - Start processing test/spotify/session_53.pcap
# 2025-12-15 15:01:19,267 - root - INFO - Start processing test/spotify/session_130.pcap
# 2025-12-15 15:01:19,269 - root - INFO - Start processing test/spotify/session_50.pcap
# 2025-12-15 15:01:19,272 - root - INFO - Start processing test/spotify/session_45.pcap
# 2025-12-15 15:01:19,274 - root - INFO - Start processing test/spotify/session_28.pcap
# 2025-12-15 15:01:19,277 - root - INFO - Start processing test/spotify/session_59.pcap
# 2025-12-15 15:01:19,279 - root - INFO - Start processing test/skype/session_67.pcap
# 2025-12-15 15:01:19,282 - root - INFO - Start processing test/skype/session_46.pcap
# 2025-12-15 15:01:19,285 - root - INFO - Start processing test/skype/session_405.pcap
# 2025-12-15 15:01:19,288 - root - INFO - Start processing test/skype/session_1161.pcap
# 2025-12-15 15:01:19,291 - root - INFO - Start processing test/skype/session_327.pcap
# 2025-12-15 15:01:19,294 - root - INFO - Start processing test/skype/session_311.pcap
# 2025-12-15 15:01:19,298 - root - INFO - Start processing test/skype/session_1050.pcap
# 2025-12-15 15:01:19,300 - root - INFO - Start processing test/skype/session_4.pcap
# 2025-12-15 15:01:19,303 - root - INFO - Start processing test/skype/session_207.pcap
# 2025-12-15 15:01:19,305 - root - INFO - Start processing test/skype/session_30.pcap
# 2025-12-15 15:01:19,307 - root - INFO - Start processing test/skype/session_379.pcap
# 2025-12-15 15:01:19,310 - root - INFO - Start processing test/skype/session_1051.pcap
# 2025-12-15 15:01:19,313 - root - INFO - Start processing test/skype/session_227.pcap
# 2025-12-15 15:01:19,316 - root - INFO - Start processing test/skype/session_437.pcap
# 2025-12-15 15:01:19,319 - root - INFO - Start processing test/skype/session_1172.pcap
# 2025-12-15 15:01:19,322 - root - INFO - Start processing test/skype/session_86.pcap
# 2025-12-15 15:01:19,324 - root - INFO - Start processing test/skype/session_32.pcap
# 2025-12-15 15:01:19,328 - root - INFO - Start processing test/skype/session_22.pcap
# 2025-12-15 15:01:19,330 - root - INFO - Start processing test/skype/session_66.pcap
# 2025-12-15 15:01:19,332 - root - INFO - Start processing test/skype/session_16.pcap
# 2025-12-15 15:01:19,334 - root - INFO - Start processing test/skype/session_167.pcap
# 2025-12-15 15:01:19,337 - root - INFO - Start processing test/skype/session_2629.pcap
# 2025-12-15 15:01:19,341 - root - INFO - Start processing test/skype/session_297.pcap
# 2025-12-15 15:01:19,345 - root - INFO - Start processing test/skype/session_105.pcap
# 2025-12-15 15:01:19,348 - root - INFO - Start processing test/skype/session_1088.pcap
# 2025-12-15 15:01:19,351 - root - INFO - Start processing test/skype/session_397.pcap
# 2025-12-15 15:01:19,353 - root - INFO - Start processing test/skype/session_47.pcap
# 2025-12-15 15:01:19,356 - root - INFO - Start processing test/ftp/session_5007.pcap
# 2025-12-15 15:01:19,359 - root - INFO - Start processing test/ftp/session_46.pcap
# 2025-12-15 15:01:19,361 - root - INFO - Start processing test/ftp/session_63.pcap
# 2025-12-15 15:01:19,363 - root - INFO - Start processing test/ftp/session_5015.pcap
# 2025-12-15 15:01:19,365 - root - INFO - Start processing test/ftp/session_5002.pcap
# 2025-12-15 15:01:19,368 - root - INFO - Start processing test/ftp/session_10.pcap
# 2025-12-15 15:01:19,371 - root - INFO - Start processing test/ftp/session_129.pcap
# 2025-12-15 15:01:19,374 - root - INFO - Start processing test/ftp/session_64.pcap
# 2025-12-15 15:01:19,376 - root - INFO - Start processing test/ftp/session_164.pcap
# 2025-12-15 15:01:19,378 - root - INFO - Start processing test/ftp/session_153.pcap
# 2025-12-15 15:01:19,381 - root - INFO - Start processing test/ftp/session_5020.pcap
# 2025-12-15 15:01:19,383 - root - INFO - Start processing test/ftp/session_5021.pcap
# 2025-12-15 15:01:19,386 - root - INFO - Start processing test/ftp/session_126.pcap
# 2025-12-15 15:01:19,388 - root - INFO - Start processing test/ftp/session_5023.pcap
# 2025-12-15 15:01:19,390 - root - INFO - Start processing test/ftp/session_163.pcap
# 2025-12-15 15:01:19,393 - root - INFO - Start processing test/voipbuster/session_639.pcap
# 2025-12-15 15:01:19,396 - root - INFO - Start processing test/voipbuster/session_46.pcap
# 2025-12-15 15:01:19,398 - root - INFO - Start processing test/voipbuster/session_752.pcap
# 2025-12-15 15:01:19,400 - root - INFO - Start processing test/voipbuster/session_88.pcap
# 2025-12-15 15:01:19,402 - root - INFO - Start processing test/voipbuster/session_22.pcap
# 2025-12-15 15:01:19,404 - root - INFO - Start processing test/voipbuster/session_159.pcap
# 2025-12-15 15:01:19,407 - root - INFO - Start processing test/voipbuster/session_39.pcap
# 2025-12-15 15:01:19,410 - root - INFO - Start processing test/voipbuster/session_1.pcap
# 2025-12-15 15:01:19,412 - root - INFO - Start processing test/voipbuster/session_37.pcap
# 2025-12-15 15:01:19,415 - root - INFO - Start processing test/voipbuster/session_132.pcap
# 2025-12-15 15:01:19,417 - root - INFO - Start processing test/voipbuster/session_35.pcap
# 2025-12-15 15:01:19,420 - root - INFO - Start processing test/voipbuster/session_759.pcap
# 2025-12-15 15:01:19,422 - root - INFO - Start processing test/voipbuster/session_36.pcap
# 2025-12-15 15:01:19,424 - root - INFO - Start processing test/vimeo/session_81.pcap
# 2025-12-15 15:01:19,426 - root - INFO - Start processing test/vimeo/session_24.pcap
# 2025-12-15 15:01:19,429 - root - INFO - Start processing test/vimeo/session_62.pcap
# 2025-12-15 15:01:19,431 - root - INFO - Start processing test/vimeo/session_106.pcap
# 2025-12-15 15:01:19,433 - root - INFO - Start processing test/vimeo/session_236.pcap
# 2025-12-15 15:01:19,435 - root - INFO - Start processing test/vimeo/session_226.pcap
# 2025-12-15 15:01:19,438 - root - INFO - Start processing test/vimeo/session_105.pcap
# 2025-12-15 15:01:19,441 - root - INFO - Start processing test/vimeo/session_237.pcap
# 2025-12-15 15:01:19,443 - root - INFO - Start processing test/vimeo/session_233.pcap
# 2025-12-15 15:01:19,446 - root - INFO - Start processing test/youtube/session_54.pcap
# 2025-12-15 15:01:19,448 - root - INFO - Start processing test/youtube/session_339.pcap
# 2025-12-15 15:01:19,451 - root - INFO - Start processing test/youtube/session_355.pcap
# 2025-12-15 15:01:19,454 - root - INFO - Start processing test/youtube/session_196.pcap
# 2025-12-15 15:01:19,456 - root - INFO - Start processing test/youtube/session_322.pcap
# 2025-12-15 15:01:19,459 - root - INFO - Start processing test/youtube/session_323.pcap
# 2025-12-15 15:01:19,461 - root - INFO - Start processing test/youtube/session_333.pcap
# 2025-12-15 15:01:19,464 - root - INFO - Start processing test/youtube/session_321.pcap
# 2025-12-15 15:01:19,466 - root - INFO - Start processing test/youtube/session_304.pcap
# 2025-12-15 15:01:19,468 - root - INFO - Start processing test/youtube/session_347.pcap
# 2025-12-15 15:01:19,470 - root - INFO - Start processing test/hangout/session_9795.pcap
# 2025-12-15 15:01:19,472 - root - INFO - Start processing test/hangout/session_2348.pcap
# 2025-12-15 15:01:19,475 - root - INFO - Start processing test/hangout/session_8780.pcap
# 2025-12-15 15:01:19,477 - root - INFO - Start processing test/hangout/session_5364.pcap
# 2025-12-15 15:01:19,479 - root - INFO - Start processing test/hangout/session_23.pcap
# 2025-12-15 15:01:19,481 - root - INFO - Start processing test/hangout/session_7639.pcap
# 2025-12-15 15:01:19,483 - root - INFO - Start processing test/hangout/session_12359.pcap
# 2025-12-15 15:01:19,485 - root - INFO - Start processing test/hangout/session_2398.pcap
# 2025-12-15 15:01:19,487 - root - INFO - Start processing test/hangout/session_9162.pcap
# 2025-12-15 15:01:19,491 - root - INFO - Start processing test/hangout/session_21.pcap
# 2025-12-15 15:01:19,497 - root - INFO - Start processing test/hangout/session_4.pcap
# 2025-12-15 15:01:19,499 - root - INFO - Start processing test/hangout/session_7913.pcap
# 2025-12-15 15:01:19,502 - root - INFO - Start processing test/hangout/session_1858.pcap
# 2025-12-15 15:01:19,505 - root - INFO - Start processing test/hangout/session_313.pcap
# 2025-12-15 15:01:19,508 - root - INFO - Start processing test/hangout/session_10016.pcap
# 2025-12-15 15:01:19,510 - root - INFO - Start processing test/hangout/session_12670.pcap
# 2025-12-15 15:01:19,512 - root - INFO - Start processing test/hangout/session_58.pcap
# 2025-12-15 15:01:19,514 - root - INFO - Start processing test/hangout/session_22.pcap
# 2025-12-15 15:01:19,516 - root - INFO - Start processing test/hangout/session_11456.pcap
# 2025-12-15 15:01:19,519 - root - INFO - Start processing test/hangout/session_1.pcap
# 2025-12-15 15:01:19,521 - root - INFO - Start processing test/hangout/session_6913.pcap
# 2025-12-15 15:01:19,523 - root - INFO - Start processing test/hangout/session_121.pcap
# 2025-12-15 15:01:19,527 - root - INFO - Start processing test/hangout/session_1092.pcap
# 2025-12-15 15:01:19,529 - root - INFO - Start processing test/hangout/session_9202.pcap
# 2025-12-15 15:01:19,532 - root - INFO - Start processing test/hangout/session_8783.pcap
# 2025-12-15 15:01:19,535 - root - INFO - Start processing test/hangout/session_40.pcap
# 2025-12-15 15:01:19,537 - root - INFO - Start processing test/hangout/session_12364.pcap
# 2025-12-15 15:01:19,540 - root - INFO - Start processing test/hangout/session_8237.pcap
# 2025-12-15 15:01:19,542 - root - INFO - Start processing test/hangout/session_6380.pcap
# 2025-12-15 15:01:19,543 - root - INFO - Start processing test/hangout/session_1099.pcap
# 2025-12-15 15:01:19,545 - root - INFO - Start processing test/hangout/session_41.pcap
# 2025-12-15 15:01:19,548 - root - INFO - Start processing test/hangout/session_177.pcap
# 2025-12-15 15:01:19,550 - root - INFO - Start processing test/hangout/session_12984.pcap
# 2025-12-15 15:01:19,553 - root - INFO - Start processing test/icq/session_9.pcap
# 2025-12-15 15:01:19,555 - root - INFO - Start processing test/scp/session_3026.pcap
# 2025-12-15 15:01:19,557 - root - INFO - Start processing test/scp/session_4264.pcap
# 2025-12-15 15:01:19,560 - root - INFO - Start processing test/scp/session_46.pcap
# 2025-12-15 15:01:19,562 - root - INFO - Start processing test/scp/session_2652.pcap
# 2025-12-15 15:01:19,564 - root - INFO - Start processing test/scp/session_3640.pcap
# 2025-12-15 15:01:19,569 - root - INFO - Start processing test/scp/session_1720.pcap
# 2025-12-15 15:01:19,571 - root - INFO - Start processing test/scp/session_119.pcap
# 2025-12-15 15:01:19,574 - root - INFO - Start processing test/scp/session_3032.pcap
# 2025-12-15 15:01:19,576 - root - INFO - Start processing test/scp/session_2782.pcap
# 2025-12-15 15:01:19,578 - root - INFO - Start processing test/scp/session_965.pcap
# 2025-12-15 15:01:19,580 - root - INFO - Start processing test/scp/session_38.pcap
# 2025-12-15 15:01:19,583 - root - INFO - Start processing test/scp/session_93.pcap
# 2025-12-15 15:01:19,587 - root - INFO - Start processing test/scp/session_62.pcap
# 2025-12-15 15:01:19,590 - root - INFO - Start processing test/scp/session_55.pcap
# 2025-12-15 15:01:19,592 - root - INFO - Start processing test/scp/session_61.pcap
# 2025-12-15 15:01:19,594 - root - INFO - Start processing test/scp/session_2755.pcap
# 2025-12-15 15:01:19,598 - root - INFO - Start processing test/scp/session_1751.pcap
# 2025-12-15 15:01:19,601 - root - INFO - Start processing test/scp/session_915.pcap
# 2025-12-15 15:01:19,603 - root - INFO - Start processing test/scp/session_2476.pcap
# 2025-12-15 15:01:19,605 - root - INFO - Start processing test/scp/session_52.pcap
# 2025-12-15 15:01:19,608 - root - INFO - Start processing test/scp/session_4090.pcap
# 2025-12-15 15:01:19,611 - root - INFO - Start processing test/scp/session_4100.pcap
# 2025-12-15 15:01:19,613 - root - INFO - Start processing test/scp/session_2383.pcap
# 2025-12-15 15:01:19,615 - root - INFO - Start processing test/scp/session_1895.pcap
# 2025-12-15 15:01:19,618 - root - INFO - Start processing test/scp/session_2900.pcap
# 2025-12-15 15:01:19,620 - root - INFO - Start processing test/scp/session_650.pcap
# 2025-12-15 15:01:19,623 - root - INFO - Start processing test/scp/session_1178.pcap
# 2025-12-15 15:01:19,625 - root - INFO - Start processing test/scp/session_2064.pcap
# 2025-12-15 15:01:19,627 - root - INFO - Start processing test/scp/session_86.pcap
# 2025-12-15 15:01:19,629 - root - INFO - Start processing test/scp/session_4162.pcap
# 2025-12-15 15:01:19,632 - root - INFO - Start processing test/scp/session_1536.pcap
# 2025-12-15 15:01:19,635 - root - INFO - Start processing test/scp/session_1554.pcap
# 2025-12-15 15:01:19,637 - root - INFO - Start processing test/scp/session_651.pcap
# 2025-12-15 15:01:19,639 - root - INFO - Start processing test/scp/session_3001.pcap
# 2025-12-15 15:01:19,641 - root - INFO - Start processing test/scp/session_2684.pcap
# 2025-12-15 15:01:19,644 - root - INFO - Start processing test/scp/session_2094.pcap
# 2025-12-15 15:01:19,646 - root - INFO - Start processing test/scp/session_811.pcap
# 2025-12-15 15:01:19,648 - root - INFO - Start processing test/scp/session_2384.pcap
# 2025-12-15 15:01:19,650 - root - INFO - Start processing test/scp/session_151.pcap
# 2025-12-15 15:01:19,652 - root - INFO - Start processing test/scp/session_94.pcap
# 2025-12-15 15:01:19,654 - root - INFO - Start processing test/scp/session_2357.pcap
# 2025-12-15 15:01:19,657 - root - INFO - Start processing test/scp/session_48.pcap
# 2025-12-15 15:01:19,659 - root - INFO - Start processing test/scp/session_43.pcap
# 2025-12-15 15:01:19,661 - root - INFO - Start processing test/scp/session_4302.pcap
# 2025-12-15 15:01:19,664 - root - INFO - Start processing test/scp/session_1575.pcap
# 2025-12-15 15:01:19,667 - root - INFO - Start processing test/scp/session_549.pcap
# 2025-12-15 15:01:19,669 - root - INFO - Start processing test/scp/session_125.pcap
# 2025-12-15 15:01:19,671 - root - INFO - Start processing test/scp/session_3137.pcap
# 2025-12-15 15:01:19,673 - root - INFO - Start processing test/scp/session_65.pcap
# 2025-12-15 15:01:19,675 - root - INFO - Start processing test/scp/session_126.pcap
# 2025-12-15 15:01:19,678 - root - INFO - Start processing test/scp/session_4080.pcap
# 2025-12-15 15:01:19,684 - root - INFO - Start processing test/scp/session_3492.pcap
# 2025-12-15 15:01:19,687 - root - INFO - Start processing test/scp/session_137.pcap
# 2025-12-15 15:01:19,690 - root - INFO - Start processing test/scp/session_885.pcap
# 2025-12-15 15:01:19,693 - root - INFO - Start processing test/aim/session_40.pcap
# 2025-12-15 15:01:19,695 - root - INFO - Start processing test/aim/session_41.pcap
# 2025-12-15 15:01:19,697 - root - INFO - Start processing test/email/session_75.pcap
# 2025-12-15 15:01:19,700 - root - INFO - Start processing test/email/session_42.pcap
# 2025-12-15 15:01:19,702 - root - INFO - Start processing test/email/session_64.pcap
# 2025-12-15 15:01:19,704 - root - INFO - Start processing test/email/session_1.pcap
# 2025-12-15 15:01:19,706 - root - INFO - Start processing test/email/session_40.pcap
# 2025-12-15 15:01:19,708 - root - INFO - Start processing test/facebook/session_118.pcap
# 2025-12-15 15:01:19,712 - root - INFO - Start processing test/facebook/session_5033.pcap
# 2025-12-15 15:01:19,714 - root - INFO - Start processing test/facebook/session_5027.pcap
# 2025-12-15 15:01:19,716 - root - INFO - Start processing test/facebook/session_4774.pcap
# 2025-12-15 15:01:19,718 - root - INFO - Start processing test/facebook/session_30.pcap
# 2025-12-15 15:01:19,720 - root - INFO - Start processing test/facebook/session_5024.pcap
# 2025-12-15 15:01:19,723 - root - INFO - Start processing test/facebook/session_45.pcap
# 2025-12-15 15:01:19,726 - root - INFO - Start processing test/facebook/session_4732.pcap
# 2025-12-15 15:01:19,729 - root - INFO - Start processing test/gmail/session_168.pcap
# 2025-12-15 15:01:19,731 - root - INFO - Start processing test/gmail/session_330.pcap
# 2025-12-15 15:01:19,734 - root - INFO - Start processing test/gmail/session_55.pcap
# 2025-12-15 15:01:19,736 - root - INFO - Start processing test/gmail/session_13.pcap
# 2025-12-15 15:01:19,739 - root - INFO - Start processing test/gmail/session_3.pcap
# 2025-12-15 15:01:19,741 - root - INFO - Start processing test/gmail/session_17.pcap
# 2025-12-15 15:01:19,743 - root - INFO - Start processing test/gmail/session_182.pcap
# 2025-12-15 15:01:19,745 - root - INFO - Start processing test/gmail/session_378.pcap
# 2025-12-15 15:01:19,747 - root - INFO - Start processing test/gmail/session_1.pcap
# 2025-12-15 15:01:19,783 - root - INFO - Start processing ISCX-VPN-2016/filtered/flow/train_val_split_